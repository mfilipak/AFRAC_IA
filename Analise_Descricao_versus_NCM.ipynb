# %% [markdown]
# # Descrição x NCM
#
#
# Identificar um NCM através da Descrição do Produto.

# %%
import pandas as pd
import numpy as np
import warnings

from gensim.models import Word2Vec
from sentence_transformers import SentenceTransformer
import joblib
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option('display.max_columns', 64)
pd.set_option('display.max_rows', 100000)
pd.set_option('float_format', '{:f}'.format)
pd.options.display.max_colwidth = None

# %%
def convert_lower_case(data):
    return np.char.lower(data)

# %%
def remove_punctuation(data):
    symbols = "ãƒâ‰‡!\"#$%&()*+-./:;<=>?@[\]^_`{|}~\n"
    for i in range(len(symbols)):
        data = np.char.replace(data, symbols[i], ' ')
        data = np.char.replace(data, "  ", " ")
    data = np.char.replace(data, ',', '')
    return data

# %%
def remove_stop_words(data,stop_words):
    words = word_tokenize(str(data))
    new_text = ""
    for w in words:
        if w not in stop_words and len(w) > 1:
            new_text = new_text + " " + w
    return new_text

# %%
def remove_apostrophe(data):
    return np.char.replace(data, "'", "")

# %%
def preprocess(data):
    data = convert_lower_case(data) #data.lower()
    data = remove_punctuation(data) #remove comma seperately
    data = remove_apostrophe(data)
    stop_words = stopwords.words('portuguese')
    data = remove_stop_words(data, stop_words)
    return data

# %% [markdown]
# ## Carga e limpeza dos dados

# %%
df = pd.read_csv('./notas_doadas.csv',sep=',',encoding='utf-8')
df['descricao_limpa'] = df['xProd'].apply(lambda row: preprocess(row.lower()))
df.drop_duplicates(subset=['descricao_limpa'],inplace=True)
df.head()
# Out:
#    Unnamed: 0  CFOP       NCM cEAN cEANTrib cProd  indTot      qCom     qTrib  \
# 0           0  5102  64019200    0        0     1       1  2.000000  2.000000
# 1           1  5102  64019200    0        0     2       1  2.000000  2.000000
# 2           2  5102  64034000    0        0     3       1  2.000000  2.000000
# 3           3  5102  39233000    0        0     4       1  5.000000  5.000000
# 4           4  5102  20079990    0        0  1609       1 20.000000 20.000000
#
#   uCom uTrib      vProd     vUnCom    vUnTrib  \
# 0   UN    UN 107.000000  53.500000  53.500000
# 1   UN    UN 107.000000  53.500000  53.500000
# 2   UN    UN 240.000000 120.000000 120.000000
# 3   UN    UN 150.000000  30.000000  30.000000
# 4   UN    UN  26.800000   1.340000   1.340000
#
#                                               xProd comb  CEST  nItemPed  \
# 0  PAR DE SAPATO DE SEGURANÃƒÂ‡A MASCULINO NÃ‚Âº 39    0     0         0
# 1            PAR DE SAPATO DE SEGURANÃƒÂ‡A NÃ‚Âº 40    0     0         0
# 2             PAR DE COTURNO DE CADARÃƒÂ‡O NÃ‚Âº 40    0     0         0
# 3                           GARRAFA TÃƒÂ‰RMICA 5 LT    0     0         0
# 4                                BANANA C/ D. LEITE    0     0         0
#
#   indEscala  EXTIPI xPed    vDesc cBenef nFCI med   vOutro   vFrete rastro  \
# 0         0       0    0 0.000000      0    0   0 0.000000 0.000000      0
# 1         0       0    0 0.000000      0    0   0 0.000000 0.000000      0
# 2         0       0    0 0.000000      0    0   0 0.000000 0.000000      0
# 3         0       0    0 0.000000      0    0   0 0.000000 0.000000      0
# 4         0       0    0 0.000000      0    0   0 0.000000 0.000000      0
#
#                     descricao_limpa
# 0   par sapato seguran masculino 39
# 1             par sapato seguran 40
# 2              par coturno cadar 40
# 3                  garrafa rmica lt
# 4                      banana leite

# %% [markdown]
# ## Tokenização

# %%
train_sentences = list(df['descricao_limpa'].str.lower().values)
tokenized_sent = []
for s in train_sentences:
    tokenized_sent.append(word_tokenize(s.lower()))
tokenized_sent[:5]
# Out:
# [['par', 'sapato', 'seguran', 'masculino', '39'],
#  ['par', 'sapato', 'seguran', '40'],
#  ['par', 'coturno', 'cadar', '40'],
#  ['garrafa', 'rmica', 'lt'],
#  ['banana', 'leite']]

# %% [markdown]
# ## Cria Modelo

# %%
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
tagged_data = [TaggedDocument(d, [i]) for i, d in enumerate(tokenized_sent)]

# %%
model = Doc2Vec(tagged_data, vector_size = 50, window = 2, min_count = 1, epochs = 200)
model.wv.vocab
# Out:
# {'par': <gensim.models.keyedvectors.Vocab at 0x20b7e8b7f88>,
#  'sapato': <gensim.models.keyedvectors.Vocab at 0x20b7e8b96c8>,
#  'seguran': <gensim.models.keyedvectors.Vocab at 0x20b7e8b9708>,
#  'masculino': <gensim.models.keyedvectors.Vocab at 0x20b7e8b9748>,
#  '39': <gensim.models.keyedvectors.Vocab at 0x20b7e8b9808>,
#  '40': <gensim.models.keyedvectors.Vocab at 0x20b7e8b9888>,
#  'coturno': <gensim.models.keyedvectors.Vocab at 0x20b7e8b98c8>,
#  'cadar': <gensim.models.keyedvectors.Vocab at 0x20b7e8b9908>,
#  'garrafa': <gensim.models.keyedvectors.Vocab at 0x20b7e8b97c8>,
#  'rmica': <gensim.models.keyedvectors.Vocab at 0x20b7e8b9848>,
#  'lt': <gensim.models.keyedvectors.Vocab at 0x20b7e8b9948>,
#  'banana': <gensim.models.keyedvectors.Vocab at 0x20b7e8b9988>,
#  'leite': <gensim.models.keyedvectors.Vocab at 0x20b7e8b99c8>,
#  'bolinho': <gensim.models.keyedvectors.Vocab at 0x20b7e8b9a08>,
#  'aipim': <gensim.models.keyedvectors.Vocab at 0x20b7e8b9a48>,
#  'cachorrinho': <gensim.models.keyedvectors.Vocab at 0x20b7e8b9a88>,
#  'folhado': <gensim.models.keyedvectors.Vocab at 0x20b7e8b9ac8>,
#  'coxinha': <gensim.models.keyedvectors.Vocab at 0x20b7e8b9b08>,
#  'empada': <gensim.models.keyedvectors.Vocab at 0x20b7e8b9b48>,
#  'frango': <gensim.models.keyedvectors.Vocab at 0x20b7e8b9b88>,
#  'pastel': <gensim.models.keyedvectors.Vocab at 0x20b7e8b9bc8>,
#  'suico': <gensim.models.keyedvectors.Vocab at 0x20b7e8b9c08>,
#  'vol': <gensim.models.keyedvectors.Vocab at 0x20b7e8b9c48>,
#  'au': <gensim.models.keyedvectors.Vocab at 0x20b7e8b9c88>,
#  'vent': <gensim.models.keyedvectors.Vocab at 0x20b7e8b9cc8>,
#  'berinjela': <gensim.models.keyedvectors.Vocab at 0x20b7e8b9d08>,
#  'defletor': <gensim.models.keyedvectors.Vocab at 0x20b7e8b9d48>,
#  'correia': <gensim.models.keyedvectors.Vocab at 0x20b7e8b9d88>,
#  'motor': <gensim.models.keyedvectors.Vocab at 0x20b7e8b9dc8>,
#  'fuel': <gensim.models.keyedvectors.Vocab at 0x20b7e8b9e08>,
#  'system': <gensim.models.keyedvectors.Vocab at 0x20b7e8b9e48>,
#  'cleaner': <gensim.models.keyedvectors.Vocab at 0x20b7e8b9e88>,
#  'injecti': <gensim.models.keyedvectors.Vocab at 0x20b7e8b9ec8>,
#  'toalhas': <gensim.models.keyedvectors.Vocab at 0x20b7e8b9f08>,
#  'papel': <gensim.models.keyedvectors.Vocab at 0x20b7e8b9f48>,
#  'interf': <gensim.models.keyedvectors.Vocab at 0x20b7e8b9f88>,
#  'br': <gensim.models.keyedvectors.Vocab at 0x20b7e8b9fc8>,
#  '100': <gensim.models.keyedvectors.Vocab at 0x20b7e8bc048>,
#  'cel': <gensim.models.keyedvectors.Vocab at 0x20b7e8bc088>,
#  '21x20': <gensim.models.keyedvectors.Vocab at 0x20b7e8bc0c8>,
#  '1000': <gensim.models.keyedvectors.Vocab at 0x20b7e8bc108>,
#  'dobr': <gensim.models.keyedvectors.Vocab at 0x20b7e8bc148>,
#  'higienico': <gensim.models.keyedvectors.Vocab at 0x20b7e8bc188>,
#  'neutro': <gensim.models.keyedvectors.Vocab at 0x20b7e8bc1c8>,
#  'fofinho': <gensim.models.keyedvectors.Vocab at 0x20b7e8bc208>,
#  'absolute': <gensim.models.keyedvectors.Vocab at 0x20b7e8bc248>,
#  '12': <gensim.models.keyedvectors.Vocab at 0x20b7e8bc288>,
#  'dupla': <gensim.models.keyedvectors.Vocab at 0x20b7e8bc2c8>,
#  'hp': <gensim.models.keyedvectors.Vocab at 0x20b7e8bc308>,
#  '16gb': <gensim.models.keyedvectors.Vocab at 0x20b7e8bc348>,
#  '2rx4': <gensim.models.keyedvectors.Vocab at 0x20b7e8bc388>,
#  'pc3l': <gensim.models.keyedvectors.Vocab at 0x20b7e8bc3c8>,
#  '12800r': <gensim.models.keyedvectors.Vocab at 0x20b7e8bc408>,
#  '11': <gensim.models.keyedvectors.Vocab at 0x20b7e8bc448>,
#  'kit': <gensim.models.keyedvectors.Vocab at 0x20b7e8bc488>,
#  '713985': <gensim.models.keyedvectors.Vocab at 0x20b7e8bc4c8>,
#  'b21': <gensim.models.keyedvectors.Vocab at 0x20b7e8bc508>,
#  'hpe': <gensim.models.keyedvectors.Vocab at 0x20b7e8bc548>,
#  '32gb': <gensim.models.keyedvectors.Vocab at 0x20b7e8bc588>,
#  '1x32gb': <gensim.models.keyedvectors.Vocab at 0x20b7e8bc5c8>,
#  'quad': <gensim.models.keyedvectors.Vocab at 0x20b7e8bc608>,
#  'rank': <gensim.models.keyedvectors.Vocab at 0x20b7e8bc648>,
#  'x4': <gensim.models.keyedvectors.Vocab at 0x20b7e8bc688>,
#  'pc3': <gensim.models.keyedvectors.Vocab at 0x20b7e8bc6c8>,
#  '14900l': <gensim.models.keyedvectors.Vocab at 0x20b7e8bc708>,
#  '708643': <gensim.models.keyedvectors.Vocab at 0x20b7e8bc748>,
#  'cartucho': <gensim.models.keyedvectors.Vocab at 0x20b7e8bc788>,
#  'toner': <gensim.models.keyedvectors.Vocab at 0x20b7e8bc7c8>,
#  'impressora': <gensim.models.keyedvectors.Vocab at 0x20b7e8bc808>,
#  'lexmark': <gensim.models.keyedvectors.Vocab at 0x20b7e8bc848>,
#  'cx510': <gensim.models.keyedvectors.Vocab at 0x20b7e8bc888>,
#  '410': <gensim.models.keyedvectors.Vocab at 0x20b7e8bc8c8>,
#  'amarelo': <gensim.models.keyedvectors.Vocab at 0x20b7e8bc908>,
#  '1loc': <gensim.models.keyedvectors.Vocab at 0x20b7e8bc948>,
#  'preto': <gensim.models.keyedvectors.Vocab at 0x20b7e8bc988>,
#  'ciano': <gensim.models.keyedvectors.Vocab at 0x20b7e8bc9c8>,
#  'recipiente': <gensim.models.keyedvectors.Vocab at 0x20b7e8bca08>,
#  'residuos': <gensim.models.keyedvectors.Vocab at 0x20b7e8bca48>,
#  'c54x': <gensim.models.keyedvectors.Vocab at 0x20b7e8bca88>,
#  'x54x': <gensim.models.keyedvectors.Vocab at 0x20b7e8bcac8>,
#  'magenta': <gensim.models.keyedvectors.Vocab at 0x20b7e8bcb08>,
#  'cafe': <gensim.models.keyedvectors.Vocab at 0x20b7e8bcb48>,
#  'acucar': <gensim.models.keyedvectors.Vocab at 0x20b7e8bcb88>,
#  'refinado': <gensim.models.keyedvectors.Vocab at 0x20b7e8bcbc8>,
#  'adocante': <gensim.models.keyedvectors.Vocab at 0x20b7e8bcc08>,
#  '200ml': <gensim.models.keyedvectors.Vocab at 0x20b7e8bcc48>,
#  'tapete': <gensim.models.keyedvectors.Vocab at 0x20b7e8bcc88>,
#  'vinil': <gensim.models.keyedvectors.Vocab at 0x20b7e8bccc8>,
#  '100cm': <gensim.models.keyedvectors.Vocab at 0x20b7e8bcd08>,
#  '80cm': <gensim.models.keyedvectors.Vocab at 0x20b7e8bcd48>,
#  'cor': <gensim.models.keyedvectors.Vocab at 0x20b7e8bcd88>,
#  'vinho': <gensim.models.keyedvectors.Vocab at 0x20b7e8bcdc8>,
#  'letras': <gensim.models.keyedvectors.Vocab at 0x20b7e8bce08>,
#  'bege': <gensim.models.keyedvectors.Vocab at 0x20b7e8bce48>,
#  'cfe': <gensim.models.keyedvectors.Vocab at 0x20b7e8bce88>,
#  'modelo': <gensim.models.keyedvectors.Vocab at 0x20b7e8bcec8>,
#  'anexo': <gensim.models.keyedvectors.Vocab at 0x20b7e8bcf08>,
#  '160cm': <gensim.models.keyedvectors.Vocab at 0x20b7e8bcf48>,
#  'pastilhas': <gensim.models.keyedvectors.Vocab at 0x20b7e8bcf88>,
#  'freio': <gensim.models.keyedvectors.Vocab at 0x20b7e8bcfc8>,
#  'dianteira': <gensim.models.keyedvectors.Vocab at 0x20b7e8bf048>,
#  'fluido': <gensim.models.keyedvectors.Vocab at 0x20b7e8bf088>,
#  'troca': <gensim.models.keyedvectors.Vocab at 0x20b7e8bf0c8>,
#  'geral': <gensim.models.keyedvectors.Vocab at 0x20b7e8bf108>,
#  'oleo': <gensim.models.keyedvectors.Vocab at 0x20b7e8bf148>,
#  'diesel': <gensim.models.keyedvectors.Vocab at 0x20b7e8bf188>,
#  '15w40': <gensim.models.keyedvectors.Vocab at 0x20b7e8bf1c8>,
#  '3l': <gensim.models.keyedvectors.Vocab at 0x20b7e8bf208>,
#  'filtro': <gensim.models.keyedvectors.Vocab at 0x20b7e8bf248>,
#  'lubrificante': <gensim.models.keyedvectors.Vocab at 0x20b7e8bf288>,
#  'gerador': <gensim.models.keyedvectors.Vocab at 0x20b7e8bf2c8>,
#  'energia': <gensim.models.keyedvectors.Vocab at 0x20b7e8bf308>,
#  'carregador': <gensim.models.keyedvectors.Vocab at 0x20b7e8bf348>,
#  'pilhas': <gensim.models.keyedvectors.Vocab at 0x20b7e8bf388>,
#  'aaa': <gensim.models.keyedvectors.Vocab at 0x20b7e479408>,
#  '1100mah': <gensim.models.keyedvectors.Vocab at 0x20b7e277648>,
#  'fx': <gensim.models.keyedvectors.Vocab at 0x20b7e277108>,
#  'c13': <gensim.models.keyedvectors.Vocab at 0x20b36dbba88>,
#  'flex': <gensim.models.keyedvectors.Vocab at 0x20b7e1680c8>,
#  'pilha': <gensim.models.keyedvectors.Vocab at 0x20b7e168b48>,
#  'recarregavel': <gensim.models.keyedvectors.Vocab at 0x20b7e168548>,
#  '12v': <gensim.models.keyedvectors.Vocab at 0x20b7e168908>,
#  'gold': <gensim.models.keyedvectors.Vocab at 0x20b7e168bc8>,
#  'placa': <gensim.models.keyedvectors.Vocab at 0x20b7e168b88>,
#  '130x400mm': <gensim.models.keyedvectors.Vocab at 0x20b7e1689c8>,
#  'avery': <gensim.models.keyedvectors.Vocab at 0x20b7e1684c8>,
#  'cinza': <gensim.models.keyedvectors.Vocab at 0x20b7e168b08>,
#  'traseira': <gensim.models.keyedvectors.Vocab at 0x20b7e168608>,
#  'cp': <gensim.models.keyedvectors.Vocab at 0x20b7e48c188>,
#  '63': <gensim.models.keyedvectors.Vocab at 0x20b7e48c388>,
#  'triac': <gensim.models.keyedvectors.Vocab at 0x20b7e48cd08>,
#  'indutor': <gensim.models.keyedvectors.Vocab at 0x20b7e48c4c8>,
#  'le2': <gensim.models.keyedvectors.Vocab at 0x20b7e8bf3c8>,
#  '2k': <gensim.models.keyedvectors.Vocab at 0x20b7e8bf408>,
#  '110v': <gensim.models.keyedvectors.Vocab at 0x20b7e8bf448>,
#  'can': <gensim.models.keyedvectors.Vocab at 0x20b7e8bf488>,
#  'al': <gensim.models.keyedvectors.Vocab at 0x20b7e8bf4c8>,
#  'pp': <gensim.models.keyedvectors.Vocab at 0x20b7e8bf508>,
#  '60uf': <gensim.models.keyedvectors.Vocab at 0x20b7e8bf548>,
#  '250v': <gensim.models.keyedvectors.Vocab at 0x20b7e8bf588>,
#  'b32360a2': <gensim.models.keyedvectors.Vocab at 0x20b7e8bf5c8>,
#  'conector': <gensim.models.keyedvectors.Vocab at 0x20b7e8bf608>,
#  'molex': <gensim.models.keyedvectors.Vocab at 0x20b7e8bf648>,
#  'pinos': <gensim.models.keyedvectors.Vocab at 0x20b7e8bf688>,
#  'femea': <gensim.models.keyedvectors.Vocab at 0x20b7e8bf6c8>,
#  'teclado': <gensim.models.keyedvectors.Vocab at 0x20b7e8bf708>,
#  'notebook': <gensim.models.keyedvectors.Vocab at 0x20b7e8bf748>,
#  'lenovo': <gensim.models.keyedvectors.Vocab at 0x20b7e8bf788>,
#  'componentes': <gensim.models.keyedvectors.Vocab at 0x20b7e8bf7c8>,
#  'eletr': <gensim.models.keyedvectors.Vocab at 0x20b7e8bf808>,
#  'nicos': <gensim.models.keyedvectors.Vocab at 0x20b7e8bf848>,
#  'acr': <gensim.models.keyedvectors.Vocab at 0x20b7e8bf888>,
#  'sbr': <gensim.models.keyedvectors.Vocab at 0x20b7e8bf8c8>,
#  'suv': <gensim.models.keyedvectors.Vocab at 0x20b7e8bf908>,
#  'tvt': <gensim.models.keyedvectors.Vocab at 0x20b7e8bf948>,
#  'algodao': <gensim.models.keyedvectors.Vocab at 0x20b7e8bf988>,
#  'egipcio': <gensim.models.keyedvectors.Vocab at 0x20b7e8bf9c8>,
#  'f100': <gensim.models.keyedvectors.Vocab at 0x20b7e8bfa08>,
#  'a2': <gensim.models.keyedvectors.Vocab at 0x20b7e8bfa48>,
#  '16l': <gensim.models.keyedvectors.Vocab at 0x20b7e8bfa88>,
#  'aguarras': <gensim.models.keyedvectors.Vocab at 0x20b7e8bfac8>,
#  '50l': <gensim.models.keyedvectors.Vocab at 0x20b7e8bfb08>,
#  'suvinil': <gensim.models.keyedvectors.Vocab at 0x20b7e8bfb48>,
#  '51577466': <gensim.models.keyedvectors.Vocab at 0x20b7e8bfb88>,
#  'esm': <gensim.models.keyedvectors.Vocab at 0x20b7e8bfbc8>,
#  'sin': <gensim.models.keyedvectors.Vocab at 0x20b7e8bfc08>,
#  'bri': <gensim.models.keyedvectors.Vocab at 0x20b7e8bfc48>,
#  '32l': <gensim.models.keyedvectors.Vocab at 0x20b7e8bfc88>,
#  'sensor': <gensim.models.keyedvectors.Vocab at 0x20b7e8bfcc8>,
#  'presen': <gensim.models.keyedvectors.Vocab at 0x20b7e8bfd08>,
#  'teto': <gensim.models.keyedvectors.Vocab at 0x20b7e8bfd48>,
#  'sob': <gensim.models.keyedvectors.Vocab at 0x20b7e8bfd88>,
#  'emb': <gensim.models.keyedvectors.Vocab at 0x20b7e8bfdc8>,
#  'exatron': <gensim.models.keyedvectors.Vocab at 0x20b7e8bfe08>,
#  'parede': <gensim.models.keyedvectors.Vocab at 0x20b7e8bfe48>,
#  'liz': <gensim.models.keyedvectors.Vocab at 0x20b7e8bfe88>,
#  'espelho': <gensim.models.keyedvectors.Vocab at 0x20b7e8bfec8>,
#  'cego': <gensim.models.keyedvectors.Vocab at 0x20b7e8bff08>,
#  '4x2': <gensim.models.keyedvectors.Vocab at 0x20b7e8bff48>,
#  'infoconv': <gensim.models.keyedvectors.Vocab at 0x20b7e8bff88>,
#  'entes': <gensim.models.keyedvectors.Vocab at 0x20b7e8bffc8>,
#  'publicos': <gensim.models.keyedvectors.Vocab at 0x20b7e8c3048>,
#  'faixa': <gensim.models.keyedvectors.Vocab at 0x20b7e8c3088>,
#  '000': <gensim.models.keyedvectors.Vocab at 0x20b7e8c30c8>,
#  '49': <gensim.models.keyedvectors.Vocab at 0x20b7e8c3108>,
#  '999': <gensim.models.keyedvectors.Vocab at 0x20b7e8c3148>,
#  'consulta': <gensim.models.keyedvectors.Vocab at 0x20b7e8c3188>,
#  'cpf': <gensim.models.keyedvectors.Vocab at 0x20b7e8c31c8>,
#  'cnpj': <gensim.models.keyedvectors.Vocab at 0x20b7e8c3208>,
#  'cnd': <gensim.models.keyedvectors.Vocab at 0x20b7e8c3248>,
#  'consultas': <gensim.models.keyedvectors.Vocab at 0x20b7e8c3288>,
#  'escova': <gensim.models.keyedvectors.Vocab at 0x20b7e8c32c8>,
#  'aco': <gensim.models.keyedvectors.Vocab at 0x20b7e8c3308>,
#  'rotativa': <gensim.models.keyedvectors.Vocab at 0x20b7e8c3348>,
#  'ondulada': <gensim.models.keyedvectors.Vocab at 0x20b7e8c3388>,
#  'rebolo': <gensim.models.keyedvectors.Vocab at 0x20b7e8c33c8>,
#  'uso': <gensim.models.keyedvectors.Vocab at 0x20b7e8c3408>,
#  'g60': <gensim.models.keyedvectors.Vocab at 0x20b7e8c3448>,
#  'norton': <gensim.models.keyedvectors.Vocab at 0x20b7e8c3488>,
#  'mastro': <gensim.models.keyedvectors.Vocab at 0x20b7e8c34c8>,
#  'revestido': <gensim.models.keyedvectors.Vocab at 0x20b7e8c3508>,
#  'cores': <gensim.models.keyedvectors.Vocab at 0x20b7e8c3548>,
#  'bandeira': <gensim.models.keyedvectors.Vocab at 0x20b7e8c3588>,
#  'luxo': <gensim.models.keyedvectors.Vocab at 0x20b7e8c35c8>,
#  'bandeiras': <gensim.models.keyedvectors.Vocab at 0x20b7e8c3608>,
#  'tce': <gensim.models.keyedvectors.Vocab at 0x20b7e8c3648>,
#  'rs': <gensim.models.keyedvectors.Vocab at 0x20b7e8c3688>,
#  'brasil': <gensim.models.keyedvectors.Vocab at 0x20b7e8c36c8>,
#  'rio': <gensim.models.keyedvectors.Vocab at 0x20b7e8c3708>,
#  'grande': <gensim.models.keyedvectors.Vocab at 0x20b7e8c3748>,
#  'sul': <gensim.models.keyedvectors.Vocab at 0x20b7e8c3788>,
#  'revestimento': <gensim.models.keyedvectors.Vocab at 0x20b7e8c37c8>,
#  'tribunal': <gensim.models.keyedvectors.Vocab at 0x20b7e8c3808>,
#  'contas': <gensim.models.keyedvectors.Vocab at 0x20b7e8c3848>,
#  'base': <gensim.models.keyedvectors.Vocab at 0x20b7e8c3888>,
#  'pedestaia': <gensim.models.keyedvectors.Vocab at 0x20b7e8c38c8>,
#  'ponteira': <gensim.models.keyedvectors.Vocab at 0x20b7e8c3908>,
#  'metalicas': <gensim.models.keyedvectors.Vocab at 0x20b7e8c3948>,
#  'prateadas': <gensim.models.keyedvectors.Vocab at 0x20b7e8c3988>,
#  'luva': <gensim.models.keyedvectors.Vocab at 0x20b7e8c39c8>,
#  'soldavel': <gensim.models.keyedvectors.Vocab at 0x20b7e8c3a08>,
#  'cl15': <gensim.models.keyedvectors.Vocab at 0x20b7e8c3a48>,
#  '25mm': <gensim.models.keyedvectors.Vocab at 0x20b7e8c3a88>,
#  'cola': <gensim.models.keyedvectors.Vocab at 0x20b7e8c3ac8>,
#  'adesivo': <gensim.models.keyedvectors.Vocab at 0x20b7e8c3b08>,
#  'pvc': <gensim.models.keyedvectors.Vocab at 0x20b7e8c3b48>,
#  '175g': <gensim.models.keyedvectors.Vocab at 0x20b7e8c3b88>,
#  'auto': <gensim.models.keyedvectors.Vocab at 0x20b7e8c3bc8>,
#  'trafo': <gensim.models.keyedvectors.Vocab at 0x20b7e8c3c08>,
#  'upsai': <gensim.models.keyedvectors.Vocab at 0x20b7e8c3c48>,
#  '5kva': <gensim.models.keyedvectors.Vocab at 0x20b7e8c3c88>,
#  'e220vs110v': <gensim.models.keyedvectors.Vocab at 0x20b7e8c3cc8>,
#  'travaprot': <gensim.models.keyedvectors.Vocab at 0x20b7e8c3d08>,
#  'slscf3805xaz': <gensim.models.keyedvectors.Vocab at 0x20b7e8c3d48>,
#  'gaveta': <gensim.models.keyedvectors.Vocab at 0x20b7e8c3d88>,
#  'adicional': <gensim.models.keyedvectors.Vocab at 0x20b7e8c3dc8>,
#  '520': <gensim.models.keyedvectors.Vocab at 0x20b7e8c3e08>,
#  'folhas': <gensim.models.keyedvectors.Vocab at 0x20b7e8c3e48>,
#  'slm4020ndxab': <gensim.models.keyedvectors.Vocab at 0x20b7e8c3e88>,
#  'printer': <gensim.models.keyedvectors.Vocab at 0x20b7e8c3ec8>,
#  'laser': <gensim.models.keyedvectors.Vocab at 0x20b7e8c3f08>,
#  'pb': <gensim.models.keyedvectors.Vocab at 0x20b7e8c3f48>,
#  '40ppm': <gensim.models.keyedvectors.Vocab at 0x20b7e8c3f88>,
#  'a4': <gensim.models.keyedvectors.Vocab at 0x20b7e8c3fc8>,
#  'evaporadora': <gensim.models.keyedvectors.Vocab at 0x20b7e8c6048>,
#  '000btus': <gensim.models.keyedvectors.Vocab at 0x20b7e8c6088>,
#  'eco': <gensim.models.keyedvectors.Vocab at 0x20b7e8c60c8>,
#  'inverter': <gensim.models.keyedvectors.Vocab at 0x20b7e8c6108>,
#  'condensadora': <gensim.models.keyedvectors.Vocab at 0x20b7e8c6148>,
#  'norma': <gensim.models.keyedvectors.Vocab at 0x20b7e8c6188>,
#  'nacional': <gensim.models.keyedvectors.Vocab at 0x20b7e8c61c8>,
#  'eletronica': <gensim.models.keyedvectors.Vocab at 0x20b7e8c6208>,
#  'abnt': <gensim.models.keyedvectors.Vocab at 0x20b7e8c6248>,
#  'nbr': <gensim.models.keyedvectors.Vocab at 0x20b7e8c6288>,
#  '14724': <gensim.models.keyedvectors.Vocab at 0x20b7e8c62c8>,
#  '2011': <gensim.models.keyedvectors.Vocab at 0x20b7e8c6308>,
#  'digital': <gensim.models.keyedvectors.Vocab at 0x20b7e8c6348>,
#  '13962': <gensim.models.keyedvectors.Vocab at 0x20b7e8c6388>,
#  '2018': <gensim.models.keyedvectors.Vocab at 0x20b7e8c63c8>,
#  'versao': <gensim.models.keyedvectors.Vocab at 0x20b7e8c6408>,
#  'corrigida': <gensim.models.keyedvectors.Vocab at 0x20b7e8c6448>,
#  '8537': <gensim.models.keyedvectors.Vocab at 0x20b7e8c6488>,
#  '2015': <gensim.models.keyedvectors.Vocab at 0x20b7e8c64c8>,
#  '9178': <gensim.models.keyedvectors.Vocab at 0x20b7e8c6508>,
#  'estacao': <gensim.models.keyedvectors.Vocab at 0x20b7e8c6548>,
#  'trabalho': <gensim.models.keyedvectors.Vocab at 0x20b7e8c6588>,
#  'dell': <gensim.models.keyedvectors.Vocab at 0x20b7e8c65c8>,
#  'precision': <gensim.models.keyedvectors.Vocab at 0x20b7e8c6608>,
#  't5820': <gensim.models.keyedvectors.Vocab at 0x20b7e8c6648>,
#  'mouse': <gensim.models.keyedvectors.Vocab at 0x20b7e8c6688>,
#  'indicador': <gensim.models.keyedvectors.Vocab at 0x20b7e8c66c8>,
#  'optico': <gensim.models.keyedvectors.Vocab at 0x20b7e8c6708>,
#  'ms116': <gensim.models.keyedvectors.Vocab at 0x20b7e8c6748>,
#  'conexao': <gensim.models.keyedvectors.Vocab at 0x20b7e8c6788>,
#  'usb': <gensim.models.keyedvectors.Vocab at 0x20b7e8c67c8>,
#  'fio': <gensim.models.keyedvectors.Vocab at 0x20b7e8c6808>,
#  'ean': <gensim.models.keyedvectors.Vocab at 0x20b7e8c6848>,
#  'code': <gensim.models.keyedvectors.Vocab at 0x20b7e8c6888>,
#  '7899864908842': <gensim.models.keyedvectors.Vocab at 0x20b7e8c68c8>,
#  'alfanumerico': <gensim.models.keyedvectors.Vocab at 0x20b7e8c6908>,
#  '107': <gensim.models.keyedvectors.Vocab at 0x20b7e8c6948>,
#  'teclas': <gensim.models.keyedvectors.Vocab at 0x20b7e8c6988>,
#  'padrao': <gensim.models.keyedvectors.Vocab at 0x20b7e8c69c8>,
#  'ptbr': <gensim.models.keyedvectors.Vocab at 0x20b7e8c6a08>,
#  'aplicacao': <gensim.models.keyedvectors.Vocab at 0x20b7e8c6a48>,
#  'maquina': <gensim.models.keyedvectors.Vocab at 0x20b7e8c6a88>,
#  'processamento': <gensim.models.keyedvectors.Vocab at 0x20b7e8c6ac8>,
#  'dados': <gensim.models.keyedvectors.Vocab at 0x20b7e8c6b08>,
#  'kb216': <gensim.models.keyedvectors.Vocab at 0x20b7e8c6b48>,
#  '789986': <gensim.models.keyedvectors.Vocab at 0x20b7e8c6b88>,
#  'monitor': <gensim.models.keyedvectors.Vocab at 0x20b7e8c6bc8>,
#  '22': <gensim.models.keyedvectors.Vocab at 0x20b7e8c6c08>,
#  'p2219h': <gensim.models.keyedvectors.Vocab at 0x20b7e8c6c48>,
#  '5397184092354': <gensim.models.keyedvectors.Vocab at 0x20b7e8c6c88>,
#  'lub': <gensim.models.keyedvectors.Vocab at 0x20b7e8c6cc8>,
#  'elf': <gensim.models.keyedvectors.Vocab at 0x20b7e8c6d08>,
#  '10': <gensim.models.keyedvectors.Vocab at 0x20b7e8c6d48>,
#  'evol': <gensim.models.keyedvectors.Vocab at 0x20b7e8c6d88>,
#  '700': <gensim.models.keyedvectors.Vocab at 0x20b7e8c6dc8>,
#  'semis': <gensim.models.keyedvectors.Vocab at 0x20b7e8c6e08>,
#  'sn': <gensim.models.keyedvectors.Vocab at 0x20b7e8c6e48>,
#  'ph6607': <gensim.models.keyedvectors.Vocab at 0x20b7e8c6e88>,
#  'fram': <gensim.models.keyedvectors.Vocab at 0x20b7e8c6ec8>,
#  'filt': <gensim.models.keyedvectors.Vocab at 0x20b7e8c6f08>,
#  'ren': <gensim.models.keyedvectors.Vocab at 0x20b7e8c6f48>,
#  'clio': <gensim.models.keyedvectors.Vocab at 0x20b7e8c6f88>,
#  'mp377': <gensim.models.keyedvectors.Vocab at 0x20b7e8c6fc8>,
#  'micr': <gensim.models.keyedvectors.Vocab at 0x20b7e8c9048>,
#  'cabine': <gensim.models.keyedvectors.Vocab at 0x20b7e8c9088>,
#  'torn': <gensim.models.keyedvectors.Vocab at 0x20b7e8c90c8>,
#  'lavatorio': <gensim.models.keyedvectors.Vocab at 0x20b7e8c9108>,
#  'balcao': <gensim.models.keyedvectors.Vocab at 0x20b7e8c9148>,
#  '1193': <gensim.models.keyedvectors.Vocab at 0x20b7e8c9188>,
#  'meber': <gensim.models.keyedvectors.Vocab at 0x20b7e8c91c8>,
#  'ligacao': <gensim.models.keyedvectors.Vocab at 0x20b7e8c9208>,
#  'flexivel': <gensim.models.keyedvectors.Vocab at 0x20b7e8c9248>,
#  '643': <gensim.models.keyedvectors.Vocab at 0x20b7e8c9288>,
#  '40cm': <gensim.models.keyedvectors.Vocab at 0x20b7e8c92c8>,
#  'wog': <gensim.models.keyedvectors.Vocab at 0x20b7e8c9308>,
#  'fitas': <gensim.models.keyedvectors.Vocab at 0x20b7e8c9348>,
#  'acabamentos': <gensim.models.keyedvectors.Vocab at 0x20b7e8c9388>,
#  'chapa': <gensim.models.keyedvectors.Vocab at 0x20b7e8c93c8>,
#  'redutor': <gensim.models.keyedvectors.Vocab at 0x20b7e8c9408>,
#  'champagne': <gensim.models.keyedvectors.Vocab at 0x20b7e8c9448>,
#  'fita': <gensim.models.keyedvectors.Vocab at 0x20b7e8c9488>,
#  'acabamento': <gensim.models.keyedvectors.Vocab at 0x20b7e8c94c8>,
#  'standart': <gensim.models.keyedvectors.Vocab at 0x20b7e8c9508>,
#  'dourado': <gensim.models.keyedvectors.Vocab at 0x20b7e8c9548>,
#  'tela': <gensim.models.keyedvectors.Vocab at 0x20b7e8c9588>,
#  'valvula': <gensim.models.keyedvectors.Vocab at 0x20b7e8c95c8>,
#  'pia': <gensim.models.keyedvectors.Vocab at 0x20b7e8c9608>,
#  'lav': <gensim.models.keyedvectors.Vocab at 0x20b7e8c9648>,
#  'ladrao': <gensim.models.keyedvectors.Vocab at 0x20b7e8c9688>,
#  '1pol': <gensim.models.keyedvectors.Vocab at 0x20b7e8c96c8>,
#  'branca': <gensim.models.keyedvectors.Vocab at 0x20b7e8c9708>,
#  'vl3': <gensim.models.keyedvectors.Vocab at 0x20b7e8c9748>,
#  'astra': <gensim.models.keyedvectors.Vocab at 0x20b7e8c9788>,
#  'anel': <gensim.models.keyedvectors.Vocab at 0x20b7e8c97c8>,
#  'cera': <gensim.models.keyedvectors.Vocab at 0x20b7e8c9808>,
#  'vedacao': <gensim.models.keyedvectors.Vocab at 0x20b7e8c9848>,
#  'wc': <gensim.models.keyedvectors.Vocab at 0x20b7e8c9888>,
#  'guia': <gensim.models.keyedvectors.Vocab at 0x20b7e8c98c8>,
#  'blukit': <gensim.models.keyedvectors.Vocab at 0x20b7e8c9908>,
#  'parafuso': <gensim.models.keyedvectors.Vocab at 0x20b7e8c9948>,
#  'fixacao': <gensim.models.keyedvectors.Vocab at 0x20b7e8c9988>,
#  '10x100mm': <gensim.models.keyedvectors.Vocab at 0x20b7e8c99c8>,
#  '02': <gensim.models.keyedvectors.Vocab at 0x20b7e8c9a08>,
#  'sifao': <gensim.models.keyedvectors.Vocab at 0x20b7e8c9a48>,
#  'extensivo': <gensim.models.keyedvectors.Vocab at 0x20b7e8c9a88>,
#  'simples': <gensim.models.keyedvectors.Vocab at 0x20b7e8c9ac8>,
#  'hig': <gensim.models.keyedvectors.Vocab at 0x20b7e8c9b08>,
#  'fofinhoclara': <gensim.models.keyedvectors.Vocab at 0x20b7e8c9b48>,
#  'folha': <gensim.models.keyedvectors.Vocab at 0x20b7e8c9b88>,
#  '04rls': <gensim.models.keyedvectors.Vocab at 0x20b7e8c9bc8>,
#  '30m': <gensim.models.keyedvectors.Vocab at 0x20b7e8c9c08>,
#  'toalha': <gensim.models.keyedvectors.Vocab at 0x20b7e8c9c48>,
#  'int': <gensim.models.keyedvectors.Vocab at 0x20b7e8c9c88>,
#  '2d': <gensim.models.keyedvectors.Vocab at 0x20b7e8c9cc8>,
#  '22x20': <gensim.models.keyedvectors.Vocab at 0x20b7e8c9d08>,
#  'premium': <gensim.models.keyedvectors.Vocab at 0x20b7e8c9d48>,
#  'c2000': <gensim.models.keyedvectors.Vocab at 0x20b7e8c9d88>,
#  'fls': <gensim.models.keyedvectors.Vocab at 0x20b7e8c9dc8>,
#  'fech': <gensim.models.keyedvectors.Vocab at 0x20b7e8c9e08>,
#  'tubular': <gensim.models.keyedvectors.Vocab at 0x20b7e8c9e48>,
#  'cromada': <gensim.models.keyedvectors.Vocab at 0x20b7e8c9e88>,
#  '601': <gensim.models.keyedvectors.Vocab at 0x20b7e8c9ec8>,
#  '602': <gensim.models.keyedvectors.Vocab at 0x20b7e8c9f08>,
#  '33': <gensim.models.keyedvectors.Vocab at 0x20b7e8c9f48>,
#  'esp': <gensim.models.keyedvectors.Vocab at 0x20b7e8c9f88>,
#  'inox': <gensim.models.keyedvectors.Vocab at 0x20b7e8c9fc8>,
#  'protetor': <gensim.models.keyedvectors.Vocab at 0x20b7e8cc048>,
#  'quina': <gensim.models.keyedvectors.Vocab at 0x20b7e8cc088>,
#  'redondo': <gensim.models.keyedvectors.Vocab at 0x20b7e8cc0c8>,
#  '04un': <gensim.models.keyedvectors.Vocab at 0x20b7e8cc108>,
#  'multikids': <gensim.models.keyedvectors.Vocab at 0x20b7e8cc148>,
#  'tinta': <gensim.models.keyedvectors.Vocab at 0x20b7e8cc188>,
#  'guache': <gensim.models.keyedvectors.Vocab at 0x20b7e8cc1c8>,
#  '018': <gensim.models.keyedvectors.Vocab at 0x20b7e8cc208>,
#  'ml': <gensim.models.keyedvectors.Vocab at 0x20b7e8cc248>,
#  '06': <gensim.models.keyedvectors.Vocab at 0x20b7e8cc288>,
#  'acrilex': <gensim.models.keyedvectors.Vocab at 0x20b7e8cc2c8>,
#  'show': <gensim.models.keyedvectors.Vocab at 0x20b7e8cc308>,
#  'color': <gensim.models.keyedvectors.Vocab at 0x20b7e8cc348>,
#  'marcador': <gensim.models.keyedvectors.Vocab at 0x20b7e8cc388>,
#  'quadro': <gensim.models.keyedvectors.Vocab at 0x20b7e8cc3c8>,
#  'branco': <gensim.models.keyedvectors.Vocab at 0x20b7e8cc408>,
#  'bic': <gensim.models.keyedvectors.Vocab at 0x20b7e8cc448>,
#  'roxo': <gensim.models.keyedvectors.Vocab at 0x20b7e8cc488>,
#  'verde': <gensim.models.keyedvectors.Vocab at 0x20b7e8cc4c8>,
#  'rosa': <gensim.models.keyedvectors.Vocab at 0x20b7e8cc508>,
#  'agulha': <gensim.models.keyedvectors.Vocab at 0x20b7e8cc548>,
#  'descartavel': <gensim.models.keyedvectors.Vocab at 0x20b7e8cc588>,
#  '13mm': <gensim.models.keyedvectors.Vocab at 0x20b7e8cc5c8>,
#  '45mm': <gensim.models.keyedvectors.Vocab at 0x20b7e8cc608>,
#  'cx': <gensim.models.keyedvectors.Vocab at 0x20b7e8cc648>,
#  'unidades': <gensim.models.keyedvectors.Vocab at 0x20b7e8cc688>,
#  '07mm': <gensim.models.keyedvectors.Vocab at 0x20b7e8cc6c8>,
#  '08mm': <gensim.models.keyedvectors.Vocab at 0x20b7e8cc708>,
#  'hidrofilo': <gensim.models.keyedvectors.Vocab at 0x20b7e8cc748>,
#  '500g': <gensim.models.keyedvectors.Vocab at 0x20b7e8cc788>,
#  'coletor': <gensim.models.keyedvectors.Vocab at 0x20b7e8cc7c8>,
#  'material': <gensim.models.keyedvectors.Vocab at 0x20b7e8cc808>,
#  'perfurocortante': <gensim.models.keyedvectors.Vocab at 0x20b7e8cc848>,
#  'cap': <gensim.models.keyedvectors.Vocab at 0x20b7e8cc888>,
#  '7lts': <gensim.models.keyedvectors.Vocab at 0x20b7e8cc8c8>,
#  'saco': <gensim.models.keyedvectors.Vocab at 0x20b7e8cc908>,
#  'residuo': <gensim.models.keyedvectors.Vocab at 0x20b7e8cc948>,
#  'infectante': <gensim.models.keyedvectors.Vocab at 0x20b7e8cc988>,
#  'superior': <gensim.models.keyedvectors.Vocab at 0x20b7e8cc9c8>,
#  'resistente': <gensim.models.keyedvectors.Vocab at 0x20b7e8cca08>,
#  '30l': <gensim.models.keyedvectors.Vocab at 0x20b7e8cca48>,
#  'descarpak': <gensim.models.keyedvectors.Vocab at 0x20b7e8cca88>,
#  'gengival': <gensim.models.keyedvectors.Vocab at 0x20b7e8ccac8>,
#  'curta': <gensim.models.keyedvectors.Vocab at 0x20b7e8ccb08>,
#  'rolete': <gensim.models.keyedvectors.Vocab at 0x20b7e8ccb48>,
#  'babador': <gensim.models.keyedvectors.Vocab at 0x20b7e8ccb88>,
#  'cunha': <gensim.models.keyedvectors.Vocab at 0x20b7e8ccbc8>,
#  'reflexiva': <gensim.models.keyedvectors.Vocab at 0x20b7e8ccc08>,
#  '20': <gensim.models.keyedvectors.Vocab at 0x20b7e8ccc48>,
#  'interdental': <gensim.models.keyedvectors.Vocab at 0x20b7e8ccc88>,
#  'extra': <gensim.models.keyedvectors.Vocab at 0x20b7e8cccc8>,
#  'fina': <gensim.models.keyedvectors.Vocab at 0x20b7e8ccd08>,
#  'media': <gensim.models.keyedvectors.Vocab at 0x20b7e8ccd48>,
#  'bock': <gensim.models.keyedvectors.Vocab at 0x20b7e8ccd88>,
#  'tira': <gensim.models.keyedvectors.Vocab at 0x20b7e8ccdc8>,
#  'transparente': <gensim.models.keyedvectors.Vocab at 0x20b7e8cce08>,
#  'poliester': <gensim.models.keyedvectors.Vocab at 0x20b7e8cce48>,
#  'guardanapo': <gensim.models.keyedvectors.Vocab at 0x20b7e8cce88>,
#  '50': <gensim.models.keyedvectors.Vocab at 0x20b7e8ccec8>,
#  'pequena': <gensim.models.keyedvectors.Vocab at 0x20b7e8ccf08>,
#  'mrdia': <gensim.models.keyedvectors.Vocab at 0x20b7e8ccf48>,
#  'met': <gensim.models.keyedvectors.Vocab at 0x20b7e8ccf88>,
#  'massa': <gensim.models.keyedvectors.Vocab at 0x20b7e8ccfc8>,
#  'corrida': <gensim.models.keyedvectors.Vocab at 0x20b7e8d1048>,
#  'novacor': <gensim.models.keyedvectors.Vocab at 0x20b7e8d1088>,
#  'fc': <gensim.models.keyedvectors.Vocab at 0x20b7e8d10c8>,
#  'nc': <gensim.models.keyedvectors.Vocab at 0x20b7e8d1108>,
#  'cobre': <gensim.models.keyedvectors.Vocab at 0x20b7e8d1148>,
#  'tixa8r': <gensim.models.keyedvectors.Vocab at 0x20b7e8d1188>,
#  'aae8r': <gensim.models.keyedvectors.Vocab at 0x20b7e8d11c8>,
#  'expansao': <gensim.models.keyedvectors.Vocab at 0x20b7e8d1208>,
#  'rosca': <gensim.models.keyedvectors.Vocab at 0x20b7e8d1248>,
#  'equal': <gensim.models.keyedvectors.Vocab at 0x20b7e8d1288>,
#  'externa': <gensim.models.keyedvectors.Vocab at 0x20b7e8d12c8>,
#  'r22': <gensim.models.keyedvectors.Vocab at 0x20b7e8d1308>,
#  'r407c': <gensim.models.keyedvectors.Vocab at 0x20b7e8d1348>,
#  'ar': <gensim.models.keyedvectors.Vocab at 0x20b7e8d1388>,
#  'condicionado': <gensim.models.keyedvectors.Vocab at 0x20b7e8d13c8>,
#  'dcl164': <gensim.models.keyedvectors.Vocab at 0x20b7e8d1408>,
#  'dml164': <gensim.models.keyedvectors.Vocab at 0x20b7e8d1448>,
#  'secador': <gensim.models.keyedvectors.Vocab at 0x20b7e8d1488>,
#  '350': <gensim.models.keyedvectors.Vocab at 0x20b7e8d14c8>,
#  'r12': <gensim.models.keyedvectors.Vocab at 0x20b7e8d1508>,
#  '134': <gensim.models.keyedvectors.Vocab at 0x20b7e8d1548>,
#  '023z5044': <gensim.models.keyedvectors.Vocab at 0x20b7e8d1588>,
#  'abacaxi': <gensim.models.keyedvectors.Vocab at 0x20b7e8d15c8>,
#  'perola': <gensim.models.keyedvectors.Vocab at 0x20b7e8d1608>,
#  'inteiro': <gensim.models.keyedvectors.Vocab at 0x20b7e8d1648>,
#  'hortela': <gensim.models.keyedvectors.Vocab at 0x20b7e8d1688>,
#  'menta': <gensim.models.keyedvectors.Vocab at 0x20b7e8d16c8>,
#  'temperos': <gensim.models.keyedvectors.Vocab at 0x20b7e8d1708>,
#  '16g': <gensim.models.keyedvectors.Vocab at 0x20b7e8d1748>,
#  'gengibre': <gensim.models.keyedvectors.Vocab at 0x20b7e8d1788>,
#  'granel': <gensim.models.keyedvectors.Vocab at 0x20b7e8d17c8>,
#  'ag': <gensim.models.keyedvectors.Vocab at 0x20b7e8d1808>,
#  'mineral': <gensim.models.keyedvectors.Vocab at 0x20b7e8d1848>,
#  'agua': <gensim.models.keyedvectors.Vocab at 0x20b7e8d1888>,
#  'pedra': <gensim.models.keyedvectors.Vocab at 0x20b7e8d18c8>,
#  'gas': <gensim.models.keyedvectors.Vocab at 0x20b7e8d1908>,
#  '5l': <gensim.models.keyedvectors.Vocab at 0x20b7e8d1948>,
#  '6185': <gensim.models.keyedvectors.Vocab at 0x20b7e8d1988>,
#  'etiq': <gensim.models.keyedvectors.Vocab at 0x20b7e8d19c8>,
#  'ink': <gensim.models.keyedvectors.Vocab at 0x20b7e8d1a08>,
#  '100fl': <gensim.models.keyedvectors.Vocab at 0x20b7e8d1a48>,
#  '2794x2159': <gensim.models.keyedvectors.Vocab at 0x20b7e8d1a88>,
#  'filip': <gensim.models.keyedvectors.Vocab at 0x20b7e8d1ac8>,
#  '04411': <gensim.models.keyedvectors.Vocab at 0x20b7e8d1b08>,
#  'envel': <gensim.models.keyedvectors.Vocab at 0x20b7e8d1b48>,
#  'ouro': <gensim.models.keyedvectors.Vocab at 0x20b7e8d1b88>,
#  '229x324': <gensim.models.keyedvectors.Vocab at 0x20b7e8d1bc8>,
#  'foroni2753': <gensim.models.keyedvectors.Vocab at 0x20b7e8d1c08>,
#  'fcd0185': <gensim.models.keyedvectors.Vocab at 0x20b7e8d1c48>,
#  'wega': <gensim.models.keyedvectors.Vocab at 0x20b7e8d1c88>,
#  'filtr': <gensim.models.keyedvectors.Vocab at 0x20b7e8d1cc8>,
#  'comb': <gensim.models.keyedvectors.Vocab at 0x20b7e8d1d08>,
#  'transit': <gensim.models.keyedvectors.Vocab at 0x20b7e8d1d48>,
#  'fap4867': <gensim.models.keyedvectors.Vocab at 0x20b7e8d1d88>,
#  'polipex': <gensim.models.keyedvectors.Vocab at 0x20b7e8d1dc8>,
#  'plus': <gensim.models.keyedvectors.Vocab at 0x20b7e8d1e08>,
#  'marfim': <gensim.models.keyedvectors.Vocab at 0x20b7e8d1e48>,
#  'silvertape': <gensim.models.keyedvectors.Vocab at 0x20b7e8d1e88>,
#  'preta': <gensim.models.keyedvectors.Vocab at 0x20b7e8d1ec8>,
#  '00010615': <gensim.models.keyedvectors.Vocab at 0x20b7e8d1f08>,
#  'alternador': <gensim.models.keyedvectors.Vocab at 0x20b7e8d1f48>,
#  'ford': <gensim.models.keyedvectors.Vocab at 0x20b7e8d1f88>,
#  'fusion': <gensim.models.keyedvectors.Vocab at 0x20b7e8d1fc8>,
#  'polia': <gensim.models.keyedvectors.Vocab at 0x20b7e8d4048>,
#  'duetto': <gensim.models.keyedvectors.Vocab at 0x20b7e8d4088>,
#  '16x4': <gensim.models.keyedvectors.Vocab at 0x20b7e8d40c8>,
#  'vipp': <gensim.models.keyedvectors.Vocab at 0x20b7e8d4108>,
#  'bco': <gensim.models.keyedvectors.Vocab at 0x20b7e8d4148>,
#  '23x20cm': <gensim.models.keyedvectors.Vocab at 0x20b7e8d4188>,
#  '5000und': <gensim.models.keyedvectors.Vocab at 0x20b7e8d41c8>,
#  'unidade': <gensim.models.keyedvectors.Vocab at 0x20b7e8d4208>,
#  'imagem': <gensim.models.keyedvectors.Vocab at 0x20b7e8d4248>,
#  'mx611': <gensim.models.keyedvectors.Vocab at 0x20b7e8d4288>,
#  '511': <gensim.models.keyedvectors.Vocab at 0x20b7e8d42c8>,
#  '310': <gensim.models.keyedvectors.Vocab at 0x20b7e8d4308>,
#  'ms610': <gensim.models.keyedvectors.Vocab at 0x20b7e8d4348>,
#  'def': <gensim.models.keyedvectors.Vocab at 0x20b7e8d4388>,
#  'criacao': <gensim.models.keyedvectors.Vocab at 0x20b7e8d43c8>,
#  'imp': <gensim.models.keyedvectors.Vocab at 0x20b7e8d4408>,
#  'cs510': <gensim.models.keyedvectors.Vocab at 0x20b7e8d4448>,
#  'cltc603lxaz': <gensim.models.keyedvectors.Vocab at 0x20b7e8d4488>,
#  '10k': <gensim.models.keyedvectors.Vocab at 0x20b7e8d44c8>,
#  'paginas': <gensim.models.keyedvectors.Vocab at 0x20b7e8d4508>,
#  'cltk603lxaz': <gensim.models.keyedvectors.Vocab at 0x20b7e8d4548>,
#  '15k': <gensim.models.keyedvectors.Vocab at 0x20b7e8d4588>,
#  'cltm603lxaz': <gensim.models.keyedvectors.Vocab at 0x20b7e8d45c8>,
#  'clty603lxaz': <gensim.models.keyedvectors.Vocab at 0x20b7e8d4608>,
#  'vid': <gensim.models.keyedvectors.Vocab at 0x20b7e8d4648>,
#  '09': <gensim.models.keyedvectors.Vocab at 0x20b7e8d4688>,
#  'vsf': <gensim.models.keyedvectors.Vocab at 0x20b7e8d46c8>,
#  'aca': <gensim.models.keyedvectors.Vocab at 0x20b7e8d4708>,
#  'sgp': <gensim.models.keyedvectors.Vocab at 0x20b7e8d4748>,
#  'sp': <gensim.models.keyedvectors.Vocab at 0x20b7e8d4788>,
#  'grav': <gensim.models.keyedvectors.Vocab at 0x20b7e8d47c8>,
#  'chassi': <gensim.models.keyedvectors.Vocab at 0x20b7e8d4808>,
#  'etiqueta': <gensim.models.keyedvectors.Vocab at 0x20b7e8d4848>,
#  'informatizada': <gensim.models.keyedvectors.Vocab at 0x20b7e8d4888>,
#  '115': <gensim.models.keyedvectors.Vocab at 0x20b7e8d48c8>,
#  '38': <gensim.models.keyedvectors.Vocab at 0x20b7e8d4908>,
#  'cm': <gensim.models.keyedvectors.Vocab at 0x20b7e8d4948>,
#  'vs': <gensim.models.keyedvectors.Vocab at 0x20b7e8d4988>,
#  'lamp': <gensim.models.keyedvectors.Vocab at 0x20b7e8d49c8>,
#  'tubo': <gensim.models.keyedvectors.Vocab at 0x20b7e8d4a08>,
#  'led': <gensim.models.keyedvectors.Vocab at 0x20b7e8d4a48>,
#  '18w': <gensim.models.keyedvectors.Vocab at 0x20b7e8d4a88>,
#  '6500k': <gensim.models.keyedvectors.Vocab at 0x20b7e8d4ac8>,
#  'biv': <gensim.models.keyedvectors.Vocab at 0x20b7e8d4b08>,
#  '120cm': <gensim.models.keyedvectors.Vocab at 0x20b7e8d4b48>,
#  '1850': <gensim.models.keyedvectors.Vocab at 0x20b7e8d4b88>,
#  'lm': <gensim.models.keyedvectors.Vocab at 0x20b7e8d4bc8>,
#  'pol': <gensim.models.keyedvectors.Vocab at 0x20b7e8d4c08>,
#  'super': <gensim.models.keyedvectors.Vocab at 0x20b7e8d4c48>,
#  'bulbo': <gensim.models.keyedvectors.Vocab at 0x20b7e8d4c88>,
#  'a60': <gensim.models.keyedvectors.Vocab at 0x20b7e8d4cc8>,
#  '7w': <gensim.models.keyedvectors.Vocab at 0x20b7e8d4d08>,
#  '27': <gensim.models.keyedvectors.Vocab at 0x20b7e8d4d48>,
#  'bivolt': <gensim.models.keyedvectors.Vocab at 0x20b7e8d4d88>,
#  'lamptubo': <gensim.models.keyedvectors.Vocab at 0x20b7e8d4dc8>,
#  '09w': <gensim.models.keyedvectors.Vocab at 0x20b7e8d4e08>,
#  '60cm': <gensim.models.keyedvectors.Vocab at 0x20b7e8d4e48>,
#  '9000lm': <gensim.models.keyedvectors.Vocab at 0x20b7e8d4e88>,
#  'vidro': <gensim.models.keyedvectors.Vocab at 0x20b7e8d4ec8>,
#  'li': <gensim.models.keyedvectors.Vocab at 0x20b7e8d4f08>,
#  'pap': <gensim.models.keyedvectors.Vocab at 0x20b7e8d4f48>,
#  'clara': <gensim.models.keyedvectors.Vocab at 0x20b7e8d4f88>,
#  'fardo': <gensim.models.keyedvectors.Vocab at 0x20b7e8d4fc8>,
#  '72': <gensim.models.keyedvectors.Vocab at 0x20b7e8d7048>,
#  'florax': <gensim.models.keyedvectors.Vocab at 0x20b7e8d7088>,
#  '1000x22x20': <gensim.models.keyedvectors.Vocab at 0x20b7e8d70c8>,
#  'ricoh': <gensim.models.keyedvectors.Vocab at 0x20b7e8d7108>,
#  'c830d': <gensim.models.keyedvectors.Vocab at 0x20b7e8d7148>,
#  '831dn': <gensim.models.keyedvectors.Vocab at 0x20b7e8d7188>,
#  'positivo': <gensim.models.keyedvectors.Vocab at 0x20b7e8d71c8>,
#  'master': <gensim.models.keyedvectors.Vocab at 0x20b7e8d7208>,
#  'c610': <gensim.models.keyedvectors.Vocab at 0x20b7e8d7248>,
#  'minipro': <gensim.models.keyedvectors.Vocab at 0x20b7e8d7288>,
#  'win': <gensim.models.keyedvectors.Vocab at 0x20b7e8d72c8>,
#  'pro': <gensim.models.keyedvectors.Vocab at 0x20b7e8d7308>,
#  'd610': <gensim.models.keyedvectors.Vocab at 0x20b7e8d7348>,
#  'windows': <gensim.models.keyedvectors.Vocab at 0x20b7e8d7388>,
#  'mou': <gensim.models.keyedvectors.Vocab at 0x20b7e8d73c8>,
#  '3bt': <gensim.models.keyedvectors.Vocab at 0x20b7e8d7408>,
#  'scr': <gensim.models.keyedvectors.Vocab at 0x20b7e8d7448>,
#  'sm': <gensim.models.keyedvectors.Vocab at 0x20b7e8d7488>,
#  '6620': <gensim.models.keyedvectors.Vocab at 0x20b7e8d74c8>,
#  'pr': <gensim.models.keyedvectors.Vocab at 0x20b7e8d7508>,
#  'fosco': <gensim.models.keyedvectors.Vocab at 0x20b7e8d7548>,
#  'delux': <gensim.models.keyedvectors.Vocab at 0x20b7e8d7588>,
#  'tcl': <gensim.models.keyedvectors.Vocab at 0x20b7e8d75c8>,
#  'abnt2': <gensim.models.keyedvectors.Vocab at 0x20b7e8d7608>,
#  'sk': <gensim.models.keyedvectors.Vocab at 0x20b7e8d7648>,
#  'pos': <gensim.models.keyedvectors.Vocab at 0x20b7e8d7688>,
#  'mon': <gensim.models.keyedvectors.Vocab at 0x20b7e8d76c8>,
#  '19': <gensim.models.keyedvectors.Vocab at 0x20b7e8d7708>,
#  'lg': <gensim.models.keyedvectors.Vocab at 0x20b7e8d7748>,
#  '20m': <gensim.models.keyedvectors.Vocab at 0x20b7e8d7788>,
#  '35': <gensim.models.keyedvectors.Vocab at 0x20b7e8d77c8>,
#  'pd': <gensim.models.keyedvectors.Vocab at 0x20b7e8d7808>,
#  '132': <gensim.models.keyedvectors.Vocab at 0x20b7e8d7848>,
#  'medium': <gensim.models.keyedvectors.Vocab at 0x20b7e8d7888>,
#  'blue': <gensim.models.keyedvectors.Vocab at 0x20b7e8d78c8>,
#  'ecolour': <gensim.models.keyedvectors.Vocab at 0x20b7e8d7908>,
#  'lee': <gensim.models.keyedvectors.Vocab at 0x20b7e8d7948>,
#  'filters': <gensim.models.keyedvectors.Vocab at 0x20b7e8d7988>,
#  'taschibra': <gensim.models.keyedvectors.Vocab at 0x20b7e8d79c8>,
#  '9w': <gensim.models.keyedvectors.Vocab at 0x20b7e8d7a08>,
#  't8': <gensim.models.keyedvectors.Vocab at 0x20b7e8d7a48>,
#  'autovolt': <gensim.models.keyedvectors.Vocab at 0x20b7e8d7a88>,
#  '7897079059366': <gensim.models.keyedvectors.Vocab at 0x20b7e8d7ac8>,
#  'tkl': <gensim.models.keyedvectors.Vocab at 0x20b7e8d7b08>,
#  '7897079051940': <gensim.models.keyedvectors.Vocab at 0x20b7e8d7b48>,
#  'oibr': <gensim.models.keyedvectors.Vocab at 0x20b7e8d7b88>,
#  'estado': <gensim.models.keyedvectors.Vocab at 0x20b7e8d7bc8>,
#  'paulo': <gensim.models.keyedvectors.Vocab at 0x20b7e8d7c08>,
#  'eletrod': <gensim.models.keyedvectors.Vocab at 0x20b7e8d7c48>,
#  'cz': <gensim.models.keyedvectors.Vocab at 0x20b7e8d7c88>,
#  'sr': <gensim.models.keyedvectors.Vocab at 0x20b7e8d7cc8>,
#  'wetzel': <gensim.models.keyedvectors.Vocab at 0x20b7e8d7d08>,
#  'tlc': <gensim.models.keyedvectors.Vocab at 0x20b7e8d7d48>,
#  'curva': <gensim.models.keyedvectors.Vocab at 0x20b7e8d7d88>,
#  'bolsa': <gensim.models.keyedvectors.Vocab at 0x20b7e8d7dc8>,
#  'abracadeira': <gensim.models.keyedvectors.Vocab at 0x20b7e8d7e08>,
#  'tampa': <gensim.models.keyedvectors.Vocab at 0x20b7e8d7e48>,
#  'postos': <gensim.models.keyedvectors.Vocab at 0x20b7e8d7e88>,
#  'juntos': <gensim.models.keyedvectors.Vocab at 0x20b7e8d7ec8>,
#  'tigre': <gensim.models.keyedvectors.Vocab at 0x20b7e8d7f08>,
#  'tomada': <gensim.models.keyedvectors.Vocab at 0x20b7e8d7f48>,
#  'horiz': <gensim.models.keyedvectors.Vocab at 0x20b7e8d7f88>,
#  '20a': <gensim.models.keyedvectors.Vocab at 0x20b7e8d7fc8>,
#  '2p': <gensim.models.keyedvectors.Vocab at 0x20b7e8da048>,
#  'pt': <gensim.models.keyedvectors.Vocab at 0x20b7e8da088>,
#  'lumibras': <gensim.models.keyedvectors.Vocab at 0x20b7e8da0c8>,
#  'ref': <gensim.models.keyedvectors.Vocab at 0x20b7e8da108>,
#  '25p': <gensim.models.keyedvectors.Vocab at 0x20b7e8da148>,
#  '113x161m': <gensim.models.keyedvectors.Vocab at 0x20b7e8da188>,
#  'estadual': <gensim.models.keyedvectors.Vocab at 0x20b7e8da1c8>,
#  '113': <gensim.models.keyedvectors.Vocab at 0x20b7e8da208>,
#  '161m': <gensim.models.keyedvectors.Vocab at 0x20b7e8da248>,
#  'cetim': <gensim.models.keyedvectors.Vocab at 0x20b7e8da288>,
#  'interfolha': <gensim.models.keyedvectors.Vocab at 0x20b7e8da2c8>,
#  '20x20': <gensim.models.keyedvectors.Vocab at 0x20b7e8da308>,
#  'bob': <gensim.models.keyedvectors.Vocab at 0x20b7e8da348>,
#  '20x22': <gensim.models.keyedvectors.Vocab at 0x20b7e8da388>,
#  '200': <gensim.models.keyedvectors.Vocab at 0x20b7e8da3c8>,
#  'personal': <gensim.models.keyedvectors.Vocab at 0x20b7e8da408>,
#  'vip': <gensim.models.keyedvectors.Vocab at 0x20b7e8da448>,
#  'glade': <gensim.models.keyedvectors.Vocab at 0x20b7e8da488>,
#  'aerosol': <gensim.models.keyedvectors.Vocab at 0x20b7e8da4c8>,
#  'lemb': <gensim.models.keyedvectors.Vocab at 0x20b7e8da508>,
#  'infancia': <gensim.models.keyedvectors.Vocab at 0x20b7e8da548>,
#  '400ml': <gensim.models.keyedvectors.Vocab at 0x20b7e8da588>,
#  'cbca': <gensim.models.keyedvectors.Vocab at 0x20b7e8da5c8>,
#  'c4810a': <gensim.models.keyedvectors.Vocab at 0x20b7e8da608>,
#  '16000pg': <gensim.models.keyedvectors.Vocab at 0x20b7e8da648>,
#  'c4811a': <gensim.models.keyedvectors.Vocab at 0x20b7e8da688>,
#  '24000pg': <gensim.models.keyedvectors.Vocab at 0x20b7e8da6c8>,
#  'c4812a': <gensim.models.keyedvectors.Vocab at 0x20b7e8da708>,
#  'c4813a': <gensim.models.keyedvectors.Vocab at 0x20b7e8da748>,
#  'bat': <gensim.models.keyedvectors.Vocab at 0x20b7e8da788>,
#  'not': <gensim.models.keyedvectors.Vocab at 0x20b7e8da7c8>,
#  'thinkpad': <gensim.models.keyedvectors.Vocab at 0x20b7e8da808>,
#  't430': <gensim.models.keyedvectors.Vocab at 0x20b7e8da848>,
#  'nr': <gensim.models.keyedvectors.Vocab at 0x20b7e8da888>,
#  'serie': <gensim.models.keyedvectors.Vocab at 0x20b7e8da8c8>,
#  '684368': <gensim.models.keyedvectors.Vocab at 0x20b7e8da908>,
#  '684370': <gensim.models.keyedvectors.Vocab at 0x20b7e8da948>,
#  'probook': <gensim.models.keyedvectors.Vocab at 0x20b7e8da988>,
#  '6460': <gensim.models.keyedvectors.Vocab at 0x20b7e8da9c8>,
#  '695870': <gensim.models.keyedvectors.Vocab at 0x20b7e8daa08>,
#  'interacao': <gensim.models.keyedvectors.Vocab at 0x20b7e8daa48>,
#  'controles': <gensim.models.keyedvectors.Vocab at 0x20b7e8daa88>,
#  'interno': <gensim.models.keyedvectors.Vocab at 0x20b7e8daac8>,
#  'externo': <gensim.models.keyedvectors.Vocab at 0x20b7e8dab08>,
#  'auditoria': <gensim.models.keyedvectors.Vocab at 0x20b7e8dab48>,
#  'programas': <gensim.models.keyedvectors.Vocab at 0x20b7e8dab88>,
#  'governamentais': <gensim.models.keyedvectors.Vocab at 0x20b7e8dabc8>,
#  'sistema': <gensim.models.keyedvectors.Vocab at 0x20b7e8dac08>,
#  'controle': <gensim.models.keyedvectors.Vocab at 0x20b7e8dac48>,
#  'administr': <gensim.models.keyedvectors.Vocab at 0x20b7e8dac88>,
#  'publica': <gensim.models.keyedvectors.Vocab at 0x20b7e8dacc8>,
#  'estudos': <gensim.models.keyedvectors.Vocab at 0x20b7e8dad08>,
#  'tematicos': <gensim.models.keyedvectors.Vocab at 0x20b7e8dad48>,
#  'direito': <gensim.models.keyedvectors.Vocab at 0x20b7e8dad88>,
#  'financeiro': <gensim.models.keyedvectors.Vocab at 0x20b7e8dadc8>,
#  'contabil': <gensim.models.keyedvectors.Vocab at 0x20b7e8dae08>,
#  'enfoque': <gensim.models.keyedvectors.Vocab at 0x20b7e8dae48>,
#  'teorico': <gensim.models.keyedvectors.Vocab at 0x20b7e8dae88>,
#  'norm': <gensim.models.keyedvectors.Vocab at 0x20b7e8daec8>,
#  'prat': <gensim.models.keyedvectors.Vocab at 0x20b7e8daf08>,
#  'curso': <gensim.models.keyedvectors.Vocab at 0x20b7e8daf48>,
#  'governamental': <gensim.models.keyedvectors.Vocab at 0x20b7e8daf88>,
#  'acordo': <gensim.models.keyedvectors.Vocab at 0x20b7e8dafc8>,
#  'abordagem': <gensim.models.keyedvectors.Vocab at 0x20b7e8df048>,
#  'pratica': <gensim.models.keyedvectors.Vocab at 0x20b7e8df088>,
#  'enfase': <gensim.models.keyedvectors.Vocab at 0x20b7e8df0c8>,
#  'teoria': <gensim.models.keyedvectors.Vocab at 0x20b7e8df108>,
#  'ed': <gensim.models.keyedvectors.Vocab at 0x20b7e8df148>,
#  'oliveira': <gensim.models.keyedvectors.Vocab at 0x20b7e8df188>,
#  'mudancas': <gensim.models.keyedvectors.Vocab at 0x20b7e8df1c8>,
#  'contabilidade': <gensim.models.keyedvectors.Vocab at 0x20b7e8df208>,
#  'reflex': <gensim.models.keyedvectors.Vocab at 0x20b7e8df248>,
#  'uniao': <gensim.models.keyedvectors.Vocab at 0x20b7e8df288>,
#  'competenc': <gensim.models.keyedvectors.Vocab at 0x20b7e8df2c8>,
#  'julgadora': <gensim.models.keyedvectors.Vocab at 0x20b7e8df308>,
#  'const': <gensim.models.keyedvectors.Vocab at 0x20b7e8df348>,
#  'fed': <gensim.models.keyedvectors.Vocab at 0x20b7e8df388>,
#  '1988': <gensim.models.keyedvectors.Vocab at 0x20b7e8df3c8>,
#  'privada': <gensim.models.keyedvectors.Vocab at 0x20b7e8df408>,
#  'moderno': <gensim.models.keyedvectors.Vocab at 0x20b7e8df448>,
#  'completo': <gensim.models.keyedvectors.Vocab at 0x20b7e8df488>,
#  'atualiz': <gensim.models.keyedvectors.Vocab at 0x20b7e8df4c8>,
#  'manual': <gensim.models.keyedvectors.Vocab at 0x20b7e8df508>,
#  'previdenciario': <gensim.models.keyedvectors.Vocab at 0x20b7e8df548>,
#  'questoes': <gensim.models.keyedvectors.Vocab at 0x20b7e8df588>,
#  'remate': <gensim.models.keyedvectors.Vocab at 0x20b7e8df5c8>,
#  'mad': <gensim.models.keyedvectors.Vocab at 0x20b7e8df608>,
#  'assento': <gensim.models.keyedvectors.Vocab at 0x20b7e8df648>,
#  'obeso': <gensim.models.keyedvectors.Vocab at 0x20b7e8df688>,
#  'unit': <gensim.models.keyedvectors.Vocab at 0x20b7e8df6c8>,
#  'encosto': <gensim.models.keyedvectors.Vocab at 0x20b7e8df708>,
#  'cabo': <gensim.models.keyedvectors.Vocab at 0x20b7e8df748>,
#  'serial': <gensim.models.keyedvectors.Vocab at 0x20b7e8df788>,
#  'sata': <gensim.models.keyedvectors.Vocab at 0x20b7e8df7c8>,
#  'cable': <gensim.models.keyedvectors.Vocab at 0x20b7e8df808>,
#  'pc': <gensim.models.keyedvectors.Vocab at 0x20b7e8df848>,
#  'cbst03': <gensim.models.keyedvectors.Vocab at 0x20b7e8df888>,
#  'sata03': <gensim.models.keyedvectors.Vocab at 0x20b7e8df8c8>,
#  'garantia': <gensim.models.keyedvectors.Vocab at 0x20b7e8df908>,
#  'meses': <gensim.models.keyedvectors.Vocab at 0x20b7e8df948>,
#  'ssd': <gensim.models.keyedvectors.Vocab at 0x20b7e8df988>,
#  '240': <gensim.models.keyedvectors.Vocab at 0x20b7e8df9c8>,
#  'gb': <gensim.models.keyedvectors.Vocab at 0x20b7e8dfa08>,
#  'kingston': <gensim.models.keyedvectors.Vocab at 0x20b7e8dfa48>,
#  'sa400s37': <gensim.models.keyedvectors.Vocab at 0x20b7e8dfa88>,
#  '240g': <gensim.models.keyedvectors.Vocab at 0x20b7e8dfac8>,
#  'iii': <gensim.models.keyedvectors.Vocab at 0x20b7e8dfb08>,
#  '25': <gensim.models.keyedvectors.Vocab at 0x20b7e8dfb48>,
#  'adaptador': <gensim.models.keyedvectors.Vocab at 0x20b7e8dfb88>,
#  'hd': <gensim.models.keyedvectors.Vocab at 0x20b7e8dfbc8>,
#  'centrium': <gensim.models.keyedvectors.Vocab at 0x20b7e8dfc08>,
#  '2535': <gensim.models.keyedvectors.Vocab at 0x20b7e8dfc48>,
#  'suporte': <gensim.models.keyedvectors.Vocab at 0x20b7e8dfc88>,
#  'desktop': <gensim.models.keyedvectors.Vocab at 0x20b7e8dfcc8>,
#  'cpu': <gensim.models.keyedvectors.Vocab at 0x20b7e8dfd08>,
#  'multilaser': <gensim.models.keyedvectors.Vocab at 0x20b7e8dfd48>,
#  'ac019': <gensim.models.keyedvectors.Vocab at 0x20b7e8dfd88>,
#  'portatil': <gensim.models.keyedvectors.Vocab at 0x20b7e8dfdc8>,
#  'medidor': <gensim.models.keyedvectors.Vocab at 0x20b7e8dfe08>,
#  'diafragma': <gensim.models.keyedvectors.Vocab at 0x20b7e8dfe48>,
#  'g10': <gensim.models.keyedvectors.Vocab at 0x20b7e8dfe88>,
#  'imob': <gensim.models.keyedvectors.Vocab at 0x20b7e8dfec8>,
#  'regulador': <gensim.models.keyedvectors.Vocab at 0x20b7e8dff08>,
#  'pressao': <gensim.models.keyedvectors.Vocab at 0x20b7e8dff48>,
#  '1est': <gensim.models.keyedvectors.Vocab at 0x20b7e8dff88>,
#  'pe': <gensim.models.keyedvectors.Vocab at 0x20b7e8dffc8>,
#  'ps': <gensim.models.keyedvectors.Vocab at 0x20b7e8e2048>,
#  '15': <gensim.models.keyedvectors.Vocab at 0x20b7e8e2088>,
#  '50m3': <gensim.models.keyedvectors.Vocab at 0x20b7e8e20c8>,
#  'anjo': <gensim.models.keyedvectors.Vocab at 0x20b7e8e2108>,
#  '5lt': <gensim.models.keyedvectors.Vocab at 0x20b7e8e2148>,
#  'acrilico': <gensim.models.keyedvectors.Vocab at 0x20b7e8e2188>,
#  '18lt': <gensim.models.keyedvectors.Vocab at 0x20b7e8e21c8>,
#  'planetaria': <gensim.models.keyedvectors.Vocab at 0x20b7e8e2208>,
#  'part': <gensim.models.keyedvectors.Vocab at 0x20b7e8e2248>,
#  'bosch': <gensim.models.keyedvectors.Vocab at 0x20b7e8e2288>,
#  '0001218174': <gensim.models.keyedvectors.Vocab at 0x20b7e8e22c8>,
#  'buchas': <gensim.models.keyedvectors.Vocab at 0x20b7e8e2308>,
#  'arranque': <gensim.models.keyedvectors.Vocab at 0x20b7e8e2348>,
#  'lucas': <gensim.models.keyedvectors.Vocab at 0x20b7e8e2388>,
#  'cassete': <gensim.models.keyedvectors.Vocab at 0x20b7e8e23c8>,
#  '18': <gensim.models.keyedvectors.Vocab at 0x20b7e8e2408>,
#  'btus': <gensim.models.keyedvectors.Vocab at 0x20b7e8e2448>,
#  'trane': <gensim.models.keyedvectors.Vocab at 0x20b7e8e2488>,
#  'painel': <gensim.models.keyedvectors.Vocab at 0x20b7e8e24c8>,
#  '30': <gensim.models.keyedvectors.Vocab at 0x20b7e8e2508>,
#  'quente': <gensim.models.keyedvectors.Vocab at 0x20b7e8e2548>,
#  'frio': <gensim.models.keyedvectors.Vocab at 0x20b7e8e2588>,
#  'fria': <gensim.models.keyedvectors.Vocab at 0x20b7e8e25c8>,
#  'dulux': <gensim.models.keyedvectors.Vocab at 0x20b7e8e2608>,
#  '26w': <gensim.models.keyedvectors.Vocab at 0x20b7e8e2648>,
#  'ourolux': <gensim.models.keyedvectors.Vocab at 0x20b7e8e2688>,
#  '6400k': <gensim.models.keyedvectors.Vocab at 0x20b7e8e26c8>,
#  'fluor': <gensim.models.keyedvectors.Vocab at 0x20b7e8e2708>,
#  '60mm': <gensim.models.keyedvectors.Vocab at 0x20b7e8e2748>,
#  'brl': <gensim.models.keyedvectors.Vocab at 0x20b7e8e2788>,
#  '2w': <gensim.models.keyedvectors.Vocab at 0x20b7e8e27c8>,
#  '4000k': <gensim.models.keyedvectors.Vocab at 0x20b7e8e2808>,
#  'rolo': <gensim.models.keyedvectors.Vocab at 0x20b7e8e2848>,
#  '5m': <gensim.models.keyedvectors.Vocab at 0x20b7e8e2888>,
#  'ip20': <gensim.models.keyedvectors.Vocab at 0x20b7e8e28c8>,
#  '437506': <gensim.models.keyedvectors.Vocab at 0x20b7e8e2908>,
#  'driver': <gensim.models.keyedvectors.Vocab at 0x20b7e8e2948>,
#  'mbl': <gensim.models.keyedvectors.Vocab at 0x20b7e8e2988>,
#  '60w': <gensim.models.keyedvectors.Vocab at 0x20b7e8e29c8>,
#  '5a': <gensim.models.keyedvectors.Vocab at 0x20b7e8e2a08>,
#  '12c': <gensim.models.keyedvectors.Vocab at 0x20b7e8e2a48>,
#  'dc': <gensim.models.keyedvectors.Vocab at 0x20b7e8e2a88>,
#  'f66046': <gensim.models.keyedvectors.Vocab at 0x20b7e8e2ac8>,
#  'mb4824': <gensim.models.keyedvectors.Vocab at 0x20b7e8e2b08>,
#  'ace': <gensim.models.keyedvectors.Vocab at 0x20b7e8e2b48>,
#  'lixa': <gensim.models.keyedvectors.Vocab at 0x20b7e8e2b88>,
#  '060': <gensim.models.keyedvectors.Vocab at 0x20b7e8e2bc8>,
#  'atlas': <gensim.models.keyedvectors.Vocab at 0x20b7e8e2c08>,
#  '339': <gensim.models.keyedvectors.Vocab at 0x20b7e8e2c48>,
#  '15a': <gensim.models.keyedvectors.Vocab at 0x20b7e8e2c88>,
#  'resimax': <gensim.models.keyedvectors.Vocab at 0x20b7e8e2cc8>,
#  '15cm': <gensim.models.keyedvectors.Vocab at 0x20b7e8e2d08>,
#  '9a': <gensim.models.keyedvectors.Vocab at 0x20b7e8e2d48>,
#  '9cm': <gensim.models.keyedvectors.Vocab at 0x20b7e8e2d88>,
#  'bom': <gensim.models.keyedvectors.Vocab at 0x20b7e8e2dc8>,
#  'lavanda': <gensim.models.keyedvectors.Vocab at 0x20b7e8e2e08>,
#  '360ml': <gensim.models.keyedvectors.Vocab at 0x20b7e8e2e48>,
#  'gratis': <gensim.models.keyedvectors.Vocab at 0x20b7e8e2e88>,
#  'maxpel': <gensim.models.keyedvectors.Vocab at 0x20b7e8e2ec8>,
#  'premisse': <gensim.models.keyedvectors.Vocab at 0x20b7e8e2f08>,
#  'sb': <gensim.models.keyedvectors.Vocab at 0x20b7e8e2f48>,
#  'liq': <gensim.models.keyedvectors.Vocab at 0x20b7e8e2f88>,
#  'erva': <gensim.models.keyedvectors.Vocab at 0x20b7e8e2fc8>,
#  'doce': <gensim.models.keyedvectors.Vocab at 0x20b7e8e5048>,
#  'soft': <gensim.models.keyedvectors.Vocab at 0x20b7e8e5088>,
#  'cristal': <gensim.models.keyedvectors.Vocab at 0x20b7e8e50c8>,
#  'ervas': <gensim.models.keyedvectors.Vocab at 0x20b7e8e5108>,
#  'processador': <gensim.models.keyedvectors.Vocab at 0x20b7e8e5148>,
#  '100mts': <gensim.models.keyedvectors.Vocab at 0x20b7e8e5188>,
#  'vermelho': <gensim.models.keyedvectors.Vocab at 0x20b7e8e51c8>,
#  'walkman': <gensim.models.keyedvectors.Vocab at 0x20b7e8e5208>,
#  'philips': <gensim.models.keyedvectors.Vocab at 0x20b7e8e5248>,
#  '2x014mm': <gensim.models.keyedvectors.Vocab at 0x20b7e8e5288>,
#  'imfap': <gensim.models.keyedvectors.Vocab at 0x20b7e8e52c8>,
#  'plug': <gensim.models.keyedvectors.Vocab at 0x20b7e8e5308>,
#  'rca': <gensim.models.keyedvectors.Vocab at 0x20b7e8e5348>,
#  'plastico': <gensim.models.keyedvectors.Vocab at 0x20b7e8e5388>,
#  'emetal': <gensim.models.keyedvectors.Vocab at 0x20b7e8e53c8>,
#  'compressao': <gensim.models.keyedvectors.Vocab at 0x20b7e8e5408>,
#  'rg6': <gensim.models.keyedvectors.Vocab at 0x20b7e8e5448>,
#  'metalico': <gensim.models.keyedvectors.Vocab at 0x20b7e8e5488>,
#  'rg59': <gensim.models.keyedvectors.Vocab at 0x20b7e8e54c8>,
#  'tpa': <gensim.models.keyedvectors.Vocab at 0x20b7e8e5508>,
#  'p2': <gensim.models.keyedvectors.Vocab at 0x20b7e8e5548>,
#  'stereo': <gensim.models.keyedvectors.Vocab at 0x20b7e8e5588>,
#  'metal': <gensim.models.keyedvectors.Vocab at 0x20b7e8e55c8>,
#  'mola': <gensim.models.keyedvectors.Vocab at 0x20b7e8e5608>,
#  'espuma': <gensim.models.keyedvectors.Vocab at 0x20b7e8e5648>,
#  'microfone': <gensim.models.keyedvectors.Vocab at 0x20b7e8e5688>,
#  'lapela': <gensim.models.keyedvectors.Vocab at 0x20b7e8e56c8>,
#  'ak010': <gensim.models.keyedvectors.Vocab at 0x20b7e8e5708>,
#  'cone': <gensim.models.keyedvectors.Vocab at 0x20b7e8e5748>,
#  'guta': <gensim.models.keyedvectors.Vocab at 0x20b7e8e5788>,
#  '28mm': <gensim.models.keyedvectors.Vocab at 0x20b7e8e57c8>,
#  '60': <gensim.models.keyedvectors.Vocab at 0x20b7e8e5808>,
#  'conicidade': <gensim.models.keyedvectors.Vocab at 0x20b7e8e5848>,
#  '04': <gensim.models.keyedvectors.Vocab at 0x20b7e8e5888>,
#  'caixa': <gensim.models.keyedvectors.Vocab at 0x20b7e8e58c8>,
#  'modular': <gensim.models.keyedvectors.Vocab at 0x20b7e8e5908>,
#  'modulo': <gensim.models.keyedvectors.Vocab at 0x20b7e8e5948>,
#  'campainha': <gensim.models.keyedvectors.Vocab at 0x20b7e8e5988>,
#  'lux2': <gensim.models.keyedvectors.Vocab at 0x20b7e8e59c8>,
#  'cigarra': <gensim.models.keyedvectors.Vocab at 0x20b7e8e5a08>,
#  'sobrepor': <gensim.models.keyedvectors.Vocab at 0x20b7e8e5a48>,
#  '26900': <gensim.models.keyedvectors.Vocab at 0x20b7e8e5a88>,
#  'embreagem': <gensim.models.keyedvectors.Vocab at 0x20b7e8e5ac8>,
#  'honda': <gensim.models.keyedvectors.Vocab at 0x20b7e8e5b08>,
#  'civic': <gensim.models.keyedvectors.Vocab at 0x20b7e8e5b48>,
#  '16v': <gensim.models.keyedvectors.Vocab at 0x20b7e8e5b88>,
#  '2005': <gensim.models.keyedvectors.Vocab at 0x20b7e8e5bc8>,
#  'retentor': <gensim.models.keyedvectors.Vocab at 0x20b7e8e5c08>,
#  'volante': <gensim.models.keyedvectors.Vocab at 0x20b7e8e5c48>,
#  'oring': <gensim.models.keyedvectors.Vocab at 0x20b7e8e5c88>,
#  'm30': <gensim.models.keyedvectors.Vocab at 0x20b7e8e5cc8>,
#  'manometro': <gensim.models.keyedvectors.Vocab at 0x20b7e8e5d08>,
#  'zamac': <gensim.models.keyedvectors.Vocab at 0x20b7e8e5d48>,
#  'mpa': <gensim.models.keyedvectors.Vocab at 0x20b7e8e5d88>,
#  'rt': <gensim.models.keyedvectors.Vocab at 0x20b7e8e5dc8>,
#  'acao': <gensim.models.keyedvectors.Vocab at 0x20b7e8e5e08>,
#  'rescisoria': <gensim.models.keyedvectors.Vocab at 0x20b7e8e5e48>,
#  'juizo': <gensim.models.keyedvectors.Vocab at 0x20b7e8e5e88>,
#  'rescindente': <gensim.models.keyedvectors.Vocab at 0x20b7e8e5ec8>,
#  'rescisorio': <gensim.models.keyedvectors.Vocab at 0x20b7e8e5f08>,
#  '2017': <gensim.models.keyedvectors.Vocab at 0x20b7e8e5f48>,
#  'forum': <gensim.models.keyedvectors.Vocab at 0x20b7e8e5f88>,
#  'accountability': <gensim.models.keyedvectors.Vocab at 0x20b7e8e5fc8>,
#  'democratica': <gensim.models.keyedvectors.Vocab at 0x20b7e8e8048>,
#  'desenho': <gensim.models.keyedvectors.Vocab at 0x20b7e8e8088>,
#  'institucional': <gensim.models.keyedvectors.Vocab at 0x20b7e8e80c8>,
#  'tribunais': <gensim.models.keyedvectors.Vocab at 0x20b7e8e8108>,
#  'conta': <gensim.models.keyedvectors.Vocab at 0x20b7e8e8148>,
#  'setor': <gensim.models.keyedvectors.Vocab at 0x20b7e8e8188>,
#  'publico': <gensim.models.keyedvectors.Vocab at 0x20b7e8e81c8>,
#  'codigo': <gensim.models.keyedvectors.Vocab at 0x20b7e8e8208>,
#  'civil': <gensim.models.keyedvectors.Vocab at 0x20b7e8e8248>,
#  'comentado': <gensim.models.keyedvectors.Vocab at 0x20b7e8e8288>,
#  'combater': <gensim.models.keyedvectors.Vocab at 0x20b7e8e82c8>,
#  'corrupcao': <gensim.models.keyedvectors.Vocab at 0x20b7e8e8308>,
#  'licitacoes': <gensim.models.keyedvectors.Vocab at 0x20b7e8e8348>,
#  'deteccao': <gensim.models.keyedvectors.Vocab at 0x20b7e8e8388>,
#  'prevencao': <gensim.models.keyedvectors.Vocab at 0x20b7e8e83c8>,
#  '2016': <gensim.models.keyedvectors.Vocab at 0x20b7e8e8408>,
#  'ferre': <gensim.models.keyedvectors.Vocab at 0x20b7e8e8448>,
#  'avancada': <gensim.models.keyedvectors.Vocab at 0x20b7e8e8488>,
#  'qestoes': <gensim.models.keyedvectors.Vocab at 0x20b7e8e84c8>,
#  'comentadas': <gensim.models.keyedvectors.Vocab at 0x20b7e8e8508>,
#  'gestao': <gensim.models.keyedvectors.Vocab at 0x20b7e8e8548>,
#  'municipal': <gensim.models.keyedvectors.Vocab at 0x20b7e8e8588>,
#  'responsabilidade': <gensim.models.keyedvectors.Vocab at 0x20b7e8e85c8>,
#  'fiscal': <gensim.models.keyedvectors.Vocab at 0x20b7e8e8608>,
#  'desafios': <gensim.models.keyedvectors.Vocab at 0x20b7e8e8648>,
#  'ex': <gensim.models.keyedvectors.Vocab at 0x20b7e8e8688>,
#  'contratacao': <gensim.models.keyedvectors.Vocab at 0x20b7e8e86c8>,
#  'direta': <gensim.models.keyedvectors.Vocab at 0x20b7e8e8708>,
#  'licitacao': <gensim.models.keyedvectors.Vocab at 0x20b7e8e8748>,
#  'contratos': <gensim.models.keyedvectors.Vocab at 0x20b7e8e8788>,
#  'administrativos': <gensim.models.keyedvectors.Vocab at 0x20b7e8e87c8>,
#  'equilibrio': <gensim.models.keyedvectors.Vocab at 0x20b7e8e8808>,
#  'economico': <gensim.models.keyedvectors.Vocab at 0x20b7e8e8848>,
#  'taxa': <gensim.models.keyedvectors.Vocab at 0x20b7e8e8888>,
#  'interna': <gensim.models.keyedvectors.Vocab at 0x20b7e8e88c8>,
#  'built': <gensim.models.keyedvectors.Vocab at 0x20b7e8e8908>,
#  'to': <gensim.models.keyedvectors.Vocab at 0x20b7e8e8948>,
#  'suit': <gensim.models.keyedvectors.Vocab at 0x20b7e8e8988>,
#  'aspectos': <gensim.models.keyedvectors.Vocab at 0x20b7e8e89c8>,
#  'controvertidos': <gensim.models.keyedvectors.Vocab at 0x20b7e8e8a08>,
#  'decorrentes': <gensim.models.keyedvectors.Vocab at 0x20b7e8e8a48>,
#  'nova': <gensim.models.keyedvectors.Vocab at 0x20b7e8e8a88>,
#  'regimes': <gensim.models.keyedvectors.Vocab at 0x20b7e8e8ac8>,
#  'proprios': <gensim.models.keyedvectors.Vocab at 0x20b7e8e8b08>,
#  'previdencia': <gensim.models.keyedvectors.Vocab at 0x20b7e8e8b48>,
#  'social': <gensim.models.keyedvectors.Vocab at 0x20b7e8e8b88>,
#  'item': <gensim.models.keyedvectors.Vocab at 0x20b7e8e8bc8>,
#  '84': <gensim.models.keyedvectors.Vocab at 0x20b7e8e8c08>,
#  'crimes': <gensim.models.keyedvectors.Vocab at 0x20b7e8e8c48>,
#  'contra': <gensim.models.keyedvectors.Vocab at 0x20b7e8e8c88>,
#  'economia': <gensim.models.keyedvectors.Vocab at 0x20b7e8e8cc8>,
#  'popular': <gensim.models.keyedvectors.Vocab at 0x20b7e8e8d08>,
#  'ordem': <gensim.models.keyedvectors.Vocab at 0x20b7e8e8d48>,
#  'metodo': <gensim.models.keyedvectors.Vocab at 0x20b7e8e8d88>,
#  'administrativo': <gensim.models.keyedvectors.Vocab at 0x20b7e8e8dc8>,
#  'malhei': <gensim.models.keyedvectors.Vocab at 0x20b7e8e8e08>,
#  'constitucional': <gensim.models.keyedvectors.Vocab at 0x20b7e8e8e48>,
#  'forens': <gensim.models.keyedvectors.Vocab at 0x20b7e8e8e88>,
#  'processual': <gensim.models.keyedvectors.Vocab at 0x20b7e8e8ec8>,
#  'ii': <gensim.models.keyedvectors.Vocab at 0x20b7e8e8f08>,
#  '51': <gensim.models.keyedvectors.Vocab at 0x20b7e8e8f48>,
#  '59': <gensim.models.keyedvectors.Vocab at 0x20b7e8e8f88>,
#  'tributario': <gensim.models.keyedvectors.Vocab at 0x20b7e8e8fc8>,
#  'processo': <gensim.models.keyedvectors.Vocab at 0x20b7e8ed048>,
#  'constitucionalidade': <gensim.models.keyedvectors.Vocab at 0x20b7e8ed088>,
#  'remedi': <gensim.models.keyedvectors.Vocab at 0x20b7e8ed0c8>,
#  'delrey': <gensim.models.keyedvectors.Vocab at 0x20b7e8ed108>,
#  'dano': <gensim.models.keyedvectors.Vocab at 0x20b7e8ed148>,
#  'moral': <gensim.models.keyedvectors.Vocab at 0x20b7e8ed188>,
#  'coletivo': <gensim.models.keyedvectors.Vocab at 0x20b7e8ed1c8>,
#  'perspectiva': <gensim.models.keyedvectors.Vocab at 0x20b7e8ed208>,
#  'direitos': <gensim.models.keyedvectors.Vocab at 0x20b7e8ed248>,
#  'fundamentais': <gensim.models.keyedvectors.Vocab at 0x20b7e8ed288>,
#  'brasileiro': <gensim.models.keyedvectors.Vocab at 0x20b7e8ed2c8>,
#  'descomplicado': <gensim.models.keyedvectors.Vocab at 0x20b7e8ed308>,
#  '16': <gensim.models.keyedvectors.Vocab at 0x20b7e8ed348>,
#  'provas': <gensim.models.keyedvectors.Vocab at 0x20b7e8ed388>,
#  'concursos': <gensim.models.keyedvectors.Vocab at 0x20b7e8ed3c8>,
#  'fazenda': <gensim.models.keyedvectors.Vocab at 0x20b7e8ed408>,
#  '14': <gensim.models.keyedvectors.Vocab at 0x20b7e8ed448>,
#  'governanca': <gensim.models.keyedvectors.Vocab at 0x20b7e8ed488>,
#  'resultados': <gensim.models.keyedvectors.Vocab at 0x20b7e8ed4c8>,
#  'visao': <gensim.models.keyedvectors.Vocab at 0x20b7e8ed508>,
#  'integrada': <gensim.models.keyedvectors.Vocab at 0x20b7e8ed548>,
#  'administracao': <gensim.models.keyedvectors.Vocab at 0x20b7e8ed588>,
#  'administ': <gensim.models.keyedvectors.Vocab at 0x20b7e8ed5c8>,
#  'hermeneutica': <gensim.models.keyedvectors.Vocab at 0x20b7e8ed608>,
#  '21': <gensim.models.keyedvectors.Vocab at 0x20b7e8ed648>,
#  'ladvog': <gensim.models.keyedvectors.Vocab at 0x20b7e8ed688>,
#  'impostos': <gensim.models.keyedvectors.Vocab at 0x20b7e8ed6c8>,
#  'federais': <gensim.models.keyedvectors.Vocab at 0x20b7e8ed708>,
#  'estaduais': <gensim.models.keyedvectors.Vocab at 0x20b7e8ed748>,
#  'municipais': <gensim.models.keyedvectors.Vocab at 0x20b7e8ed788>,
#  'improbidade': <gensim.models.keyedvectors.Vocab at 0x20b7e8ed7c8>,
#  'administrativa': <gensim.models.keyedvectors.Vocab at 0x20b7e8ed808>,
#  'temas': <gensim.models.keyedvectors.Vocab at 0x20b7e8ed848>,
#  'atuais': <gensim.models.keyedvectors.Vocab at 0x20b7e8ed888>,
#  'julgamento': <gensim.models.keyedvectors.Vocab at 0x20b7e8ed8c8>,
#  'cortes': <gensim.models.keyedvectors.Vocab at 0x20b7e8ed908>,
#  'supremas': <gensim.models.keyedvectors.Vocab at 0x20b7e8ed948>,
#  'precedente': <gensim.models.keyedvectors.Vocab at 0x20b7e8ed988>,
#  'decisao': <gensim.models.keyedvectors.Vocab at 0x20b7e8ed9c8>,
#  'recurso': <gensim.models.keyedvectors.Vocab at 0x20b7e8eda08>,
#  'diante': <gensim.models.keyedvectors.Vocab at 0x20b7e8eda48>,
#  'jurisdicao': <gensim.models.keyedvectors.Vocab at 0x20b7e8eda88>,
#  'sincronia': <gensim.models.keyedvectors.Vocab at 0x20b7e8edac8>,
#  'racionali': <gensim.models.keyedvectors.Vocab at 0x20b7e8edb08>,
#  'passo': <gensim.models.keyedvectors.Vocab at 0x20b7e8edb48>,
#  'comentando': <gensim.models.keyedvectors.Vocab at 0x20b7e8edb88>,
#  'todos': <gensim.models.keyedvectors.Vocab at 0x20b7e8edbc8>,
#  'artigos': <gensim.models.keyedvectors.Vocab at 0x20b7e8edc08>,
#  'lei': <gensim.models.keyedvectors.Vocab at 0x20b7e8edc48>,
#  '666': <gensim.models.keyedvectors.Vocab at 0x20b7e8edc88>,
#  '93': <gensim.models.keyedvectors.Vocab at 0x20b7e8edcc8>,
#  'execucao': <gensim.models.keyedvectors.Vocab at 0x20b7e8edd08>,
#  'metodologia': <gensim.models.keyedvectors.Vocab at 0x20b7e8edd48>,
#  'cientifica': <gensim.models.keyedvectors.Vocab at 0x20b7e8edd88>,
#  'ministerio': <gensim.models.keyedvectors.Vocab at 0x20b7e8eddc8>,
#  'perspectivas': <gensim.models.keyedvectors.Vocab at 0x20b7e8ede08>,
#  'doutrinarias': <gensim.models.keyedvectors.Vocab at 0x20b7e8ede48>,
#  'estatuto': <gensim.models.keyedvectors.Vocab at 0x20b7e8ede88>,
#  'ju': <gensim.models.keyedvectors.Vocab at 0x20b7e8edec8>,
#  'jurisprudencia': <gensim.models.keyedvectors.Vocab at 0x20b7e8edf08>,
#  'precedentes': <gensim.models.keyedvectors.Vocab at 0x20b7e8edf48>,
#  'cpc': <gensim.models.keyedvectors.Vocab at 0x20b7e8edf88>,
#  'novo': <gensim.models.keyedvectors.Vocab at 0x20b7e8edfc8>,
#  ...}

# %% [markdown]
# ## Testes e Análises

# %%
model.wv.most_similar('leite')
# Out:
# [('bis', 0.961297869682312),
#  ('lacta', 0.9604376554489136),
#  ('elege', 0.9524224996566772),
#  ('126g', 0.9462490081787109),
#  ('banana', 0.9457299113273621),
#  ('camponesa', 0.9351269006729126),
#  ('bombinha', 0.9139132499694824),
#  ('430ml', 0.8857569694519043),
#  ('folhado', 0.881889283657074),
#  ('erva', 0.8813177347183228)]

# %%
def print_res(train_sentences, df, test):    
    for t in test:      
        print(t[1], " | Descrição Original: ", df['xProd'].iloc[t[0]], " | NCM: ", df['NCM'].iloc[t[0]])

# %%
test_doc = word_tokenize("sapato masculino".lower())
test_doc_vector = model.infer_vector(test_doc)
model.docvecs.most_similar(positive = [test_doc_vector])
test = model.docvecs.most_similar(positive = [test_doc_vector])
print_res(train_sentences, df, test)
# Out:
# 0.8891231417655945  | Descrição Original:  PAR DE SAPATO DE SEGURANÃƒÂ‡A NÃ‚Âº 40  | NCM:  64019200
# 0.8835933208465576  | Descrição Original:  PAR DE SAPATO DE SEGURANÃƒÂ‡A MASCULINO NÃ‚Âº 39  | NCM:  64019200
# 0.8347089886665344  | Descrição Original:  SAPATO DE PREGO  | NCM:  64022000
# 0.816364049911499  | Descrição Original:  PAR DE COTURNO DE CADARÃƒÂ‡O NÃ‚Âº 40  | NCM:  64034000
# 0.7463095784187317  | Descrição Original:  CAIXA SAPATO PQ     60000 ORDENE  | NCM:  39249000
# 0.7360522747039795  | Descrição Original:  CAIXA SAPATO MD     60200 ORDENE  | NCM:  39249000
# 0.7114656567573547  | Descrição Original:  PARES DE CAIXA ACUSTICA CLARITY CL 100P  | NCM:  85182200
# 0.7097424268722534  | Descrição Original:  ACABAMENTO VP 40 .1/2 3/4 1 ABS  | NCM:  84819010
# 0.705060601234436  | Descrição Original:  CERATO 40%  | NCM:  30043290
# 0.7037459015846252  | Descrição Original:  CAIXA DE BEGÃƒÂ”NIAS COM 15 MUDAS  | NCM:  6039000

# %%
test_doc = word_tokenize(preprocess("creme de leite camponesa tp"))
test_doc_vector = model.infer_vector(test_doc)
model.docvecs.most_similar(positive = [test_doc_vector])
test = model.docvecs.most_similar(positive = [test_doc_vector])
print_res(train_sentences, df, test)
# Out:
# 0.9520816206932068  | Descrição Original:  CREME DE LEITE CAMPONESA TP 200G  | NCM:  4015021
# 0.9366070628166199  | Descrição Original:  BANANA C/ D. LEITE  | NCM:  20079990
# 0.9262491464614868  | Descrição Original:  LEITE ELEGE  | NCM:  4021010
# 0.9195842146873474  | Descrição Original:  BIS LACTA AO LEITE          126G  | NCM:  19053200
# 0.8897718787193298  | Descrição Original:  CROISSANT CHOCOLATE AO LEITE CT  | NCM:  19022000
# 0.8764390349388123  | Descrição Original:  BRIG GOURMET AO LEITE  | NCM:  20079990
# 0.8556551933288574  | Descrição Original:  BOMBINHA DOCE LEITE  | NCM:  20079990
# 0.8440322279930115  | Descrição Original:  BOMBINHA CHOCOLATE  | NCM:  20079990
# 0.8403213024139404  | Descrição Original:  LEITE FLUIDO  | NCM:  4022110
# 0.8291023373603821  | Descrição Original:  ROCAMBOLE DOCE DE LEITE  | NCM:  20079990
